# %% [markdown]
# # Embeddings from scratch

# %%
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
sentences = [
    'La inteligencia artificial es la hostia',
    'El procesamiento de lenguaje natural es una rama del aprendizaje profundo',
    "Me encanta estudar inteligencia artifical",
    "Las películas de inteligencia artificial me encantan",
    "El arendizaje profundo es una subcategoría de la inteligencia artificial",
    "Los embeddings de palabras capturan semántica",
    "PyTorch es una herramienta para aprendiaje profundo e inteligencia artificial",
]

# %%
class SkipGramData(Dataset):
    def __init__(self, corpus, window_sz= 2):
        super().__init__
        self.corpus = corpus
        self.window = window_sz
        self.vocab = list(set(token.lower() for sentence in self.corpus for token in sentence.split())) # set elimina dups y no mantiene el orden
        self.word2idx = {word: idx for idx, word in enumerate(self.vocab)}
        self.idx2word = {idx: word for word, idx in self.word2idx.items()}
        self.data = self.gen_dataset()

    def gen_dataset(self):
        # Metod for enventanado
        data = []
        for sentence in self.corpus:
            text = sentence.lower().split()
            print(text)
            for center_idx, center_word in enumerate(text):
                for offset in range(-self.window, self.window +1):
                    context_idx = center_idx + offset
                    if context_idx < 0 or context_idx >= len(text) or context_idx == center_idx: continue
                    context_word = text[context_idx]
                    data.append((self.word2idx[center_word], self.word2idx[context_word]))
        return data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

# %%
class SkipGram(nn.Module):
    def __init__(self, vocab_sz, embed_sz):
        super().__init__()
        self.embed_layer = nn.Linear(vocab_sz, embed_sz, bias = False)
        self.output_layer = nn.Linear(embed_sz, vocab_sz)

    def forward(self, x):
        return self.output_layer(self.embed_layer(x))

# %%
def train_skipgram(model, loss_function, optimizer, data_loader, epochs=100):
    for epoch in range(epochs):
        total_loss = 0
        for center, context in data_loader:
            center_vector = torch.zeros(len(data_loader.dataset.vocab))
            center_vector[center] = 1.0
            center_vector = center_vector.unsqueeze(0)
            scores = model(center_vector)

            loss = loss_function(scores, torch.tensor([context]))
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()
            total_loss += loss.item()
        print(f'epoch: {epoch}, loss: {total_loss/len(data_loader)}')

# %%
learning_rate = 0.0001

dataset = SkipGramData(sentences)
print(type(dataset.data))
data_loader = DataLoader(dataset, batch_size=1, shuffle=True)
model = SkipGram(len(dataset.vocab), embed_sz=300)
optimizer = optim.Adam(model.parameters(), lr= learning_rate)
loss_function = nn.CrossEntropyLoss()

train_skipgram(model, loss_function, optimizer, data_loader, epochs=1000)
for center_idx, context_idx in dataset.data:
    print(dataset.idx2word[center_idx],dataset.idx2word[context_idx])
# Out:
# ['la', 'inteligencia', 'artificial', 'es', 'la', 'hostia']
# ['el', 'procesamiento', 'de', 'lenguaje', 'natural', 'es', 'una', 'rama', 'del', 'aprendizaje', 'profundo']
# ['me', 'encanta', 'estudar', 'inteligencia', 'artifical']
# ['las', 'películas', 'de', 'inteligencia', 'artificial', 'me', 'encantan']
# ['el', 'arendizaje', 'profundo', 'es', 'una', 'subcategoría', 'de', 'la', 'inteligencia', 'artificial']
# ['los', 'embeddings', 'de', 'palabras', 'capturan', 'semántica']
# ['pytorch', 'es', 'una', 'herramienta', 'para', 'aprendiaje', 'profundo', 'e', 'inteligencia', 'artificial']
# <class 'list'>
# epoch: 0, loss: 3.528258436181572
# epoch: 1, loss: 3.505415624447083
# epoch: 2, loss: 3.483098129208168
# epoch: 3, loss: 3.4605692303582525
# epoch: 981, loss: 1.7697350513399317
# epoch: 982, loss: 1.7697907250918699
# epoch: 983, loss: 1.7698809494463246
# epoch: 984, loss: 1.769949801182479
# epoch: 985, loss: 1.7695869033256273
# epoch: 986, loss: 1.7704357273792952
# epoch: 987, loss: 1.7699882582332311
# epoch: 988, loss: 1.770219779751274
# epoch: 989, loss: 1.7694486463337802
# epoch: 990, loss: 1.770202108648386
# epoch: 991, loss: 1.769146500343687
# epoch: 992, loss: 1.7698517461841026
# epoch: 993, loss: 1.77024437269468
# epoch: 994, loss: 1.770127247558551
# epoch: 995, loss: 1.7695895369802968
# epoch: 996, loss: 1.7695387504743727
# epoch: 997, loss: 1.7702271945021126
# epoch: 998, loss: 1.7700303036175418
# epoch: 999, loss: 1.7697252671370345
# la inteligencia
# la artificial
# inteligencia la
# inteligencia artificial
# inteligencia es
# artificial la
# artificial inteligencia
# artificial es
# artificial la
# es inteligencia
# es artificial
# es la
# es hostia
# la artificial
# la es
# la hostia
# hostia es
# hostia la
# el procesamiento
# el de
# procesamiento el
# procesamiento de
# procesamiento lenguaje
# de el
# de procesamiento
# de lenguaje
# de natural
# lenguaje procesamiento
# lenguaje de
# lenguaje natural
# lenguaje es
# natural de
# natural lenguaje
# natural es
# natural una
# es lenguaje
# es natural
# es una
# es rama
# una natural
# una es
# una rama
# una del
# rama es
# rama una
# rama del
# rama aprendizaje
# del una
# del rama
# del aprendizaje
# del profundo
# aprendizaje rama
# aprendizaje del
# aprendizaje profundo
# profundo del
# profundo aprendizaje
# me encanta
# me estudar
# encanta me
# encanta estudar
# encanta inteligencia
# estudar me
# estudar encanta
# estudar inteligencia
# estudar artifical
# inteligencia encanta
# inteligencia estudar
# inteligencia artifical
# artifical estudar
# artifical inteligencia
# las películas
# las de
# películas las
# películas de
# películas inteligencia
# de las
# de películas
# de inteligencia
# de artificial
# inteligencia películas
# inteligencia de
# inteligencia artificial
# inteligencia me
# artificial de
# artificial inteligencia
# artificial me
# artificial encantan
# me inteligencia
# me artificial
# me encantan
# encantan artificial
# encantan me
# el arendizaje
# el profundo
# arendizaje el
# arendizaje profundo
# arendizaje es
# profundo el
# profundo arendizaje
# profundo es
# profundo una
# es arendizaje
# es profundo
# es una
# es subcategoría
# una profundo
# una es
# una subcategoría
# una de
# subcategoría es
# subcategoría una
# subcategoría de
# subcategoría la
# de una
# de subcategoría
# de la
# de inteligencia
# la subcategoría
# la de
# la inteligencia
# la artificial
# inteligencia de
# inteligencia la
# inteligencia artificial
# artificial la
# artificial inteligencia
# los embeddings
# los de
# embeddings los
# embeddings de
# embeddings palabras
# de los
# de embeddings
# de palabras
# de capturan
# palabras embeddings
# palabras de
# palabras capturan
# palabras semántica
# capturan de
# capturan palabras
# capturan semántica
# semántica palabras
# semántica capturan
# pytorch es
# pytorch una
# es pytorch
# es una
# es herramienta
# una pytorch
# una es
# una herramienta
# una para
# herramienta es
# herramienta una
# herramienta para
# herramienta aprendiaje
# para una
# para herramienta
# para aprendiaje
# para profundo
# aprendiaje herramienta
# aprendiaje para
# aprendiaje profundo
# aprendiaje e
# profundo para
# profundo aprendiaje
# profundo e
# profundo inteligencia
# e aprendiaje
# e profundo
# e inteligencia
# e artificial
# inteligencia profundo
# inteligencia e
# inteligencia artificial
# artificial e
# artificial inteligencia

# %%
for x, y in data_loader:
    print(x, y)
# Out:
# tensor([11]) tensor([25])
# tensor([16]) tensor([9])
# tensor([9]) tensor([2])
# tensor([18]) tensor([33])
# tensor([30]) tensor([4])
# tensor([30]) tensor([15])
# tensor([15]) tensor([7])
# tensor([27]) tensor([33])
# tensor([13]) tensor([30])
# tensor([32]) tensor([2])
# tensor([18]) tensor([28])
# tensor([0]) tensor([18])
# tensor([5]) tensor([3])
# tensor([2]) tensor([20])
# tensor([16]) tensor([9])
# tensor([19]) tensor([26])
# tensor([21]) tensor([18])
# tensor([32]) tensor([9])
# tensor([18]) tensor([30])
# tensor([16]) tensor([25])
# tensor([5]) tensor([12])
# tensor([9]) tensor([32])
# tensor([17]) tensor([0])
# tensor([26]) tensor([4])
# tensor([4]) tensor([2])
# tensor([21]) tensor([13])
# tensor([28]) tensor([16])
# tensor([24]) tensor([28])
# tensor([16]) tensor([21])
# tensor([2]) tensor([4])
# tensor([11]) tensor([22])
# tensor([5]) tensor([18])
# tensor([2]) tensor([0])
# tensor([16]) tensor([14])
# tensor([4]) tensor([13])
# tensor([9]) tensor([21])
# tensor([15]) tensor([30])
# tensor([20]) tensor([32])
# tensor([9]) tensor([16])
# tensor([33]) tensor([18])
# tensor([4]) tensor([30])
# tensor([22]) tensor([9])
# tensor([20]) tensor([29])
# tensor([16]) tensor([1])
# tensor([12]) tensor([10])
# tensor([21]) tensor([9])
# tensor([9]) tensor([25])
# tensor([20]) tensor([2])
# tensor([16]) tensor([30])
# tensor([8]) tensor([3])
# tensor([18]) tensor([5])
# tensor([4]) tensor([7])
# tensor([4]) tensor([18])
# tensor([18]) tensor([24])
# tensor([30]) tensor([4])
# tensor([28]) tensor([24])
# tensor([25]) tensor([11])
# tensor([24]) tensor([9])
# tensor([23]) tensor([11])
# tensor([7]) tensor([19])
# tensor([16]) tensor([28])
# tensor([4]) tensor([30])
# tensor([7]) tensor([15])
# tensor([29]) tensor([9])
# tensor([2]) tensor([16])
# tensor([9]) tensor([16])
# tensor([16]) tensor([24])
# tensor([22]) tensor([2])
# tensor([14]) tensor([0])
# tensor([9]) tensor([22])
# tensor([0]) tensor([2])
# tensor([10]) tensor([12])
# tensor([13]) tensor([30])
# tensor([25]) tensor([9])
# tensor([4]) tensor([19])
# tensor([18]) tensor([21])
# tensor([6]) tensor([7])
# tensor([18]) tensor([9])
# tensor([16]) tensor([31])
# tensor([19]) tensor([4])
# tensor([8]) tensor([5])
# tensor([30]) tensor([13])
# tensor([26]) tensor([19])
# tensor([13]) tensor([4])
# tensor([30]) tensor([4])
# tensor([23]) tensor([2])
# tensor([9]) tensor([24])
# tensor([3]) tensor([18])
# tensor([24]) tensor([18])
# tensor([9]) tensor([29])
# tensor([13]) tensor([30])
# tensor([14]) tensor([16])
# tensor([11]) tensor([2])
# tensor([16]) tensor([4])
# tensor([9]) tensor([18])
# tensor([29]) tensor([20])
# tensor([32]) tensor([20])
# tensor([30]) tensor([23])
# tensor([14]) tensor([2])
# tensor([16]) tensor([9])
# tensor([21]) tensor([16])
# tensor([29]) tensor([32])
# tensor([19]) tensor([7])
# tensor([18]) tensor([4])
# tensor([4]) tensor([13])
# tensor([18]) tensor([12])
# tensor([19]) tensor([6])
# tensor([9]) tensor([1])
# tensor([13]) tensor([31])
# tensor([11]) tensor([23])
# tensor([31]) tensor([16])
# tensor([4]) tensor([23])
# tensor([0]) tensor([17])
# tensor([2]) tensor([23])
# tensor([4]) tensor([30])
# tensor([5]) tensor([8])
# tensor([25]) tensor([22])
# tensor([2]) tensor([32])
# tensor([10]) tensor([18])
# tensor([1]) tensor([9])
# tensor([18]) tensor([17])
# tensor([22]) tensor([25])
# tensor([29]) tensor([16])
# tensor([0]) tensor([14])
# tensor([30]) tensor([13])
# tensor([4]) tensor([18])
# tensor([3]) tensor([8])
# tensor([7]) tensor([30])
# tensor([16]) tensor([13])
# tensor([13]) tensor([4])
# tensor([13]) tensor([16])
# tensor([22]) tensor([11])
# tensor([13]) tensor([21])
# tensor([16]) tensor([29])
# tensor([27]) tensor([18])
# tensor([12]) tensor([18])
# tensor([17]) tensor([18])
# tensor([27]) tensor([4])
# tensor([6]) tensor([19])
# tensor([4]) tensor([26])
# tensor([1]) tensor([16])
# tensor([30]) tensor([13])
# tensor([17]) tensor([28])
# tensor([28]) tensor([18])
# tensor([2]) tensor([11])
# tensor([4]) tensor([30])
# tensor([7]) tensor([4])
# tensor([6]) tensor([4])
# tensor([12]) tensor([5])
# tensor([18]) tensor([27])
# tensor([7]) tensor([6])
# tensor([24]) tensor([16])
# tensor([30]) tensor([16])
# tensor([4]) tensor([16])
# tensor([4]) tensor([27])
# tensor([18]) tensor([13])
# tensor([9]) tensor([16])
# tensor([31]) tensor([13])
# tensor([18]) tensor([3])
# tensor([13]) tensor([18])
# tensor([33]) tensor([27])
# tensor([23]) tensor([30])
# tensor([18]) tensor([4])
# tensor([4]) tensor([6])
# tensor([30]) tensor([18])
# tensor([2]) tensor([22])
# tensor([16]) tensor([2])
# tensor([30]) tensor([4])
# tensor([32]) tensor([29])
# tensor([2]) tensor([9])
# tensor([23]) tensor([4])
# tensor([30]) tensor([7])
# tensor([18]) tensor([0])
# tensor([25]) tensor([16])
# tensor([2]) tensor([14])
# tensor([18]) tensor([10])
# tensor([3]) tensor([5])
# tensor([28]) tensor([17])

# %%
def plot_embeddings(embedings, word2idx):
    num_samples = len(word2idx)
    tsne = TSNE(n_components=2, random_state=0)
    vectors = tsne.fit_transform(embeddings)
    plt.figure(figsize=(20,10))
    for word, idx in word2idx.items():
        plt.scatter(vectors[idx, 0], vectors[idx, 1])
        plt.annotate(word, xy=(vectors[idx, 0], vectors[idx, 1]), xytext=(5,2), 
                    textcoords='offset points', ha='right', va='bottom')
    plt.title('Word Embeddings Visualized using t-SNE')
    plt.xlabel('t-SNE Dimension 1')
    plt.ylabel(True)
    plt.show()

# %%
embeddings = model.embed_layer.weight.detach().numpy()
plot_embeddings(embeddings, dataset.word2idx)
