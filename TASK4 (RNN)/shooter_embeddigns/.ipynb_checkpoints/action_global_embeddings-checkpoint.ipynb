# %% [markdown]
# # BUILDING OF EMBEDDINGS FOR **ACTION GLOBAL**

# %%
import pandas as pd
import os
import shutil
from zipfile import ZipFile, BadZipFile
import json
import numpy as np
from torch.cuda.amp import GradScaler, autocast
from sklearn.cluster import KMeans


import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

from sklearn.cluster import KMeans
from sklearn.metrics.pairwise import euclidean_distances

print(np.__version__)
# Out:
# 1.26.4

# %% [markdown]
# ## USE GPU

# %%
def check_gpu():
    if torch.cuda.is_available():
        print("CUDA está disponible.")
        print(f"Hay {torch.cuda.device_count()} GPU(s) disponible(s).")
        for i in range(torch.cuda.device_count()):
            print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
    else:
        print("CUDA no está disponible. No hay GPU accesible.")

check_gpu()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# CUDA está disponible.
# Hay 1 GPU(s) disponible(s).
# GPU 0: NVIDIA GeForce RTX 2060

# %% [markdown]
# ## DATA PREPROCESSING: Creation of scripts list with all project scripts

# %%
metrics = pd.read_csv('metrics_attr.csv')

# Filter by Action Genre
metrics_action = metrics[(metrics['Main Genre'] == 'Action')]

# Check the filenames for collect
filenames_action = list(metrics_action['Name'])
# Create txt for made the shell script
with open('filenames_action_global.txt', 'w') as names:
     for name in filenames_action:
        names.write(name + '\n')


for project in filenames_action:
    sb3_path = f'./projects_sb3/{project}'
    if os.path.isfile(sb3_path):
        shutil.copy(sb3_path, './sb3_action_global')
        print(f'The project {project} has been success copy')
    else:
        print(f'The project {project} doesnt exists')
# Out:
# The project Abby and Grace's project.sb3 has been success copy
# The project Adventures of TreeGuy.sb3 has been success copy
# The project Ahmet-Ofer.sb3 has been success copy
# The project Aji Jesu Game.sb3 has been success copy
# The project Albedo Barrier.sb3 has been success copy
# The project Albedo Pong.sb3 has been success copy
# The project Albedo Project.sb3 has been success copy
# The project Alex and Hannah's project.sb3 has been success copy
# The project Aman and Brady Project.sb3 has been success copy
# The project Anjali and Mariana-3.sb3 has been success copy
# The project Artem Tsukasa.sb3 has been success copy
# The project Atmosphere Pong.sb3 has been success copy
# The project Avery's Life.sb3 has been success copy
# The project Beat the Robot.sb3 has been success copy
# The project Becca and Alana Climate change.sb3 has been success copy
# The project Become the Best Lumberjack.sb3 has been success copy
# The project Brendan and Hallel.sb3 has been success copy
# The project Brick Breaker remix.sb3 has been success copy
# The project Bryan and Mark's Game Project.sb3 has been success copy
# The project Building wackamole in the city of Hainsboro.sb3 has been success copy
# The project CARBON CLICKING (Arjun the other one was screwed up so I made a new one).sb3 doesnt exists
# The project CARbon Killer.sb3 has been success copy
# The project CAUSATION EVASION.sb3 has been success copy
# The project CO2 Crusher.sb3 has been success copy
# The project CO2 Drop.sb3 has been success copy
# The project CO2 Footprints.sb3 has been success copy
# The project CO2 Killer.sb3 has been success copy
# The project CO2 Stopper Copter.sb3 has been success copy
# The project CO2 Stopper.sb3 has been success copy
# The project CO2 destroyer.sb3 has been success copy
# The project CO2 fr.sb3 has been success copy
# The project CO2 journey.sb3 has been success copy
# The project Car Bike Atmosphere.sb3 has been success copy
# The project Car Game.sb3 has been success copy
# The project Car.sb3 has been success copy
# The project Carbon Annihilation.sb3 has been success copy
# The project Carbon Capture.sb3 has been success copy
# The project Carbon Clicker_(2).sb3 has been success copy
# The project Carbon Destroyer.sb3 has been success copy
# The project Carbon Footprint project.sb3 has been success copy
# The project Carbon Game by Ria and Sarah.sb3 has been success copy
# The project Carbon Game.sb3 has been success copy
# The project Carbon Maze.sb3 has been success copy
# The project Carbon Run.sb3 has been success copy
# The project Carbon Run_(2).sb3 has been success copy
# The project Cars and co2.sb3 has been success copy
# The project Catch the CO2.sb3 has been success copy
# The project Clara and Mira's Project.sb3 has been success copy
# The project Class Project Sage and Nora.sb3 has been success copy
# The project Click the cars!.sb3 has been success copy
# The project Climate Change - Caitlin & Irene.sb3 has been success copy
# The project Climate Change Catch Game.sb3 has been success copy
# The project Climate Change Choose Your Own Adventure.sb3 has been success copy
# The project Climate Change Game Hannah and Andrew.sb3 has been success copy
# The project Climate Change Game_(2).sb3 has been success copy
# The project Climate Change Game_(5).sb3 has been success copy
# The project Climate Change Game_(8).sb3 has been success copy
# The project Climate Change Game_(9).sb3 has been success copy
# The project Climate Change Mario.sb3 has been success copy
# The project Climate Change Pong Finished Version.sb3 has been success copy
# The project Climate Change Project: Saving the penguin.sb3 has been success copy
# The project Climate Change Project_(2).sb3 has been success copy
# The project Climate Change With Cars and CO2.sb3 has been success copy
# The project Climate Change and the CO2 Succa.sb3 has been success copy
# The project Climate Change project.sb3 has been success copy
# The project Climate Clikerz.sb3 has been success copy
# The project Climate Control.sb3 has been success copy
# The project Climate Control_(2).sb3 has been success copy
# The project Climate Jumper.sb3 has been success copy
# The project Climate Pong.sb3 has been success copy
# The project Climate change game!!!!.sb3 has been success copy
# The project Climate change game-jassec.sb3 has been success copy
# The project Climate change game.sb3 has been success copy
# The project Climate change- Emari Wakefield and Julia Machado.sb3 has been success copy
# The project Climate change.sb3 has been success copy
# The project Cloud Catching.sb3 has been success copy
# The project Co2 Catch.sb3 has been success copy
# The project Co2 Survival.sb3 has been success copy
# The project Cole and Ryan.sb3 has been success copy
# The project Collect Co2.sb3 has been success copy
# The project Collect the CO2.sb3 has been success copy
# The project Cool Climate Game.sb3 has been success copy
# The project Cow catch game.sb3 has been success copy
# The project Crab runner.sb3 has been success copy
# The project Crossing Guard of the Atmosphere.sb3 has been success copy
# The project Cut it out.sb3 has been success copy
# The project DO NOT PLAY THIS GAME. PLAY THE OTHER ONE!.sb3 has been success copy
# The project DON'T TOUCH THE WATER.sb3 has been success copy
# The project Daniel Scott.sb3 has been success copy
# The project Dat Albedo.sb3 has been success copy
# The project David & Peter.sb3 has been success copy
# The project Deforestation Disaster.sb3 has been success copy
# The project Deforestation Game.sb3 has been success copy
# The project Deforestation Game_(2).sb3 has been success copy
# The project Deforestation Hailey and Remi's Game.sb3 has been success copy
# The project Deforestation game.sb3 has been success copy
# The project Destroy the World.sb3 has been success copy
# The project Don't Get Burned!.sb3 has been success copy
# The project Dont Go With The Flow.sb3 has been success copy
# The project Dont break the ice remix emily and maddie.sb3 has been success copy
# The project ENOZO STOPPER.sb3 has been success copy
# The project ERIC AND ROSIE ANIMATION CHALLENGE.sb3 has been success copy
# The project Earth Vs Climate change Dodge ball game.sb3 has been success copy
# The project Earth vs. Floods.sb3 has been success copy
# The project Eat The Carbon by Barry and Kyrene.sb3 has been success copy
# The project Edie Bella Animation Challenge.sb3 has been success copy
# The project Ella and Arsema animation Challenge.sb3 has been success copy
# The project Ellie and Talia Untitled-5.sb3 has been success copy
# The project Elsa saves the world alebdo style.sb3 has been success copy
# The project Emily and haley Greenhouse effect.sb3 has been success copy
# The project Eujin and Julia.sb3 has been success copy
# The project Factory Game Thalia and Jehan.sb3 has been success copy
# The project Factory Game remix.sb3 has been success copy
# The project Factory Pollution.sb3 has been success copy
# The project FactorySimulator.sb3 has been success copy
# The project Falling Fruit Fiesta.sb3 has been success copy
# The project Farmer Sam and His Cows.sb3 has been success copy
# The project Fight Wanda the Evil Lumberjack.sb3 has been success copy
# The project Fight the Pollution!.sb3 has been success copy
# The project Flood the World.sb3 has been success copy
# The project Forest Fire Scratch Game Akash Adrien.sb3 has been success copy
# The project Forest.sb3 has been success copy
# The project Fortnite: Climate Change Edition.sb3 has been success copy
# The project Franki and Elena's game.sb3 has been success copy
# The project Future C02.sb3 has been success copy
# The project GHGs Game.sb3 has been success copy
# The project Gabe Umut-2.sb3 has been success copy
# The project Game John And Harry.sb3 has been success copy
# The project Garden Simulator 2k17.sb3 has been success copy
# The project Gil Avieli and Sam Atalla.sb3 has been success copy
# The project Global Warming Game.sb3 has been success copy
# The project Grayson Josh Animation Challenge.sb3 has been success copy
# The project Greenhouse Gases Game.sb3 has been success copy
# The project Guardian of the Forest.sb3 has been success copy
# The project Guy+Sonia-Lower the Carbon!.sb3 has been success copy
# The project Hagar and Sephora Reforestation.sb3 has been success copy
# The project Harrison And Constantinos.sb3 has been success copy
# The project Heat Havoc.sb3 has been success copy
# The project Heat absorber.sb3 has been success copy
# The project Hit the Target.sb3 has been success copy
# The project Hudson Animation Challenge.sb3 has been success copy
# The project Humanity vs Carbon vs Plants- Nolan and Chima.sb3 has been success copy
# The project Ice Blocker Climate Change Game.sb3 has been success copy
# The project Ice Cap Hero!.sb3 has been success copy
# The project Ice Pong.sb3 has been success copy
# The project Infrared Invasion.sb3 has been success copy
# The project Isabella and Sarah-3.sb3 has been success copy
# The project Island Fish Rescue.sb3 has been success copy
# The project IvGroup7s2 Max Dylan.sb3 has been success copy
# The project Jack and Zach's Epic Adventure.sb3 has been success copy
# The project JakeJaleikaAnimationChallenge.sb3 has been success copy
# The project Jocey and Natasha.sb3 has been success copy
# The project Joci and Becky Climate Change Games.sb3 has been success copy
# The project Joe and Aidan climate change slingshot thingy.sb3 has been success copy
# The project Joe and Charlie Final Project.sb3 has been success copy
# The project Julia and Meri's Game.sb3 has been success copy
# The project Jump Into Climate Change!.sb3 has been success copy
# The project KARINE AND LANCE.sb3 has been success copy
# The project Kendel and Ben's game.sb3 has been success copy
# The project Kenny Michael.sb3 has been success copy
# The project Kevin_Ben Animation Challenge.sb3 has been success copy
# The project Latifah M.Sophie N.Ava M..sb3 doesnt exists
# The project Leaf Me Alone Carbon.com.net.org.io.exe.mp3.mp4.sb3 has been success copy
# The project Lex Gigi Animation Challenge.sb3 doesnt exists
# The project Leyla and Erin-3 remix remix.sb3 has been success copy
# The project Log Samurai.sb3 has been success copy
# The project Lumberjack simulator.sb3 has been success copy
# The project Mark Jeremy.sb3 has been success copy
# The project Melica Jaycee Natsuka Climate Change Game.sb3 doesnt exists
# The project Mitigation - Elias Daniel- F Block.sb3 has been success copy
# The project Mitigation Game.sb3 has been success copy
# The project Neo Jonathan.sb3 has been success copy
# The project New Science Scratch.sb3 has been success copy
# The project Nora + Sage.sb3 has been success copy
# The project Ocean Defender.sb3 has been success copy
# The project OliviaEmilyAnimaionChalllenge.sb3 has been success copy
# The project PONG CLIMATE CHANGE.sb3 has been success copy
# The project Patrick and Elaine.sb3 has been success copy
# The project Patrick and Sawyer Climate Game.sb3 has been success copy
# The project Penguin Game.sb3 has been success copy
# The project Penguin Saver- By Holland and Andrew.sb3 has been success copy
# The project Penguin game.sb3 has been success copy
# The project Picking Up Trash Helps The World: Mitigation.sb3 has been success copy
# The project Plant Man IV.sb3 has been success copy
# The project Plant the Trees!.sb3 has been success copy
# The project Polar Bear Fixes Climate Change.sb3 has been success copy
# The project Polar Saving.sb3 has been success copy
# The project Polluted Park.sb3 has been success copy
# The project Pollution Control.sb3 has been success copy
# The project Pollution Game.sb3 has been success copy
# The project Potato's adventure.sb3 has been success copy
# The project Preventing CO2 from coming into the Earth.sb3 has been success copy
# The project Preventing Greenhouse Gases With Paul the Poler Bear.sb3 has been success copy
# The project Rambunctious Recycling.sb3 has been success copy
# The project Rebecca Chloe Animation Challenge.sb3 doesnt exists
# The project Reduce dat boi Co2 in the Atmosphere.sb3 has been success copy
# The project Reducing Meat Consumption.sb3 has been success copy
# The project Reducing Ocean Acidification.sb3 has been success copy
# The project Reforestation and Deforestation- Saving this land.sb3 has been success copy
# The project Rising Co2 Level.sb3 has been success copy
# The project Roberto and Ethan  -.sb3 has been success copy
# The project Ryan D and Weller B CC Game.sb3 has been success copy
# The project SOPHIA AND MADDIE.sb3 has been success copy
# The project STOP THOSE CARS!!!!!.sb3 has been success copy
# The project Sammie and Alex Carbon Cycle Project.sb3 has been success copy
# The project Sarita Gabe Game.sb3 has been success copy
# The project Save The Atmosphere.sb3 has been success copy
# The project Save The Fish.sb3 has been success copy
# The project Save The Ocean: A Crab Game.sb3 has been success copy
# The project Save The Trees_(3).sb3 has been success copy
# The project Save The World.sb3 has been success copy
# The project Save the Atmosphere!.sb3 has been success copy
# The project Save the Climate.sb3 has been success copy
# The project Save the Earth.sb3 has been success copy
# The project Save the Fishy.sb3 has been success copy
# The project Save the Oceans!.sb3 has been success copy
# The project Save the Planet!.sb3 has been success copy
# The project Save the Shellfish.sb3 has been success copy
# The project Save the Sky.sb3 has been success copy
# The project Save the Trees!.sb3 has been success copy
# The project Save the World from Co2!.sb3 has been success copy
# The project Save the penguin :).sb3 has been success copy
# The project Saving Squishy.sb3 has been success copy
# The project Saving The Earth One Seed At A Time.sb3 has been success copy
# The project Saving the Polar Bears.sb3 has been success copy
# The project Science Game.sb3 has been success copy
# The project Scratch CO2 Project.sb3 has been success copy
# The project Scratch Climate Change Project.sb3 has been success copy
# The project Scratch Project.sb3 has been success copy
# The project Scratch Project: Helen & Condoleezza.sb3 has been success copy
# The project Shayan and Jeff.sb3 has been success copy
# The project Sinking Penguin.sb3 has been success copy
# The project Soccer Pong.sb3 has been success copy
# The project Sofi S..sb3 has been success copy
# The project SofiaKevinAnimationChallenge.sb3 has been success copy
# The project Sophia and Mar Deforestation Game.sb3 has been success copy
# The project Sophie and Hannah's Climate Game!!!!!!!.sb3 has been success copy
# The project SophieDante Animation Challenge.sb3 has been success copy
# The project Space CO2.sb3 has been success copy
# The project Space Game 1: Climate Change.sb3 has been success copy
# The project Substantial Farming Simulator.sb3 has been success copy
# The project Sun Ray Shielder.sb3 has been success copy
# The project Super Carbon Bros.sb3 has been success copy
# The project Super Chad Bro..sb3 has been success copy
# The project Super Planty Bros (Drew and Sasha).sb3 has been success copy
# The project SuperSeaTurtleBro..sb3 has been success copy
# The project Sydney Forristall and Samuel Gordon.sb3 has been success copy
# The project Sydney _ Daniella game.sb3 has been success copy
# The project THE GLOBAL WARMING game!.sb3 has been success copy
# The project Take Action! - heymynamestrey.sb3 has been success copy
# The project Talia Celia.sb3 has been success copy
# The project Tesla CO2 Emissions.sb3 has been success copy
# The project The Awesome Lamp Game.sb3 has been success copy
# The project The Best Game You've Ever Played *No Guarentee.sb3 has been success copy
# The project The Carbon Challenge.sb3 has been success copy
# The project The Fun Ocean Game.sb3 doesnt exists
# The project The Green House Game.sb3 has been success copy
# The project The Greenhouse Effect.sb3 has been success copy
# The project The Night sky.sb3 has been success copy
# The project The Polar Bear.sb3 has been success copy
# The project Transportation Pollution.sb3 has been success copy
# The project Tree Cutting Simulator.sb3 has been success copy
# The project Tree1 Climate Game.sb3 has been success copy
# The project Trees vs LumberJack.sb3 has been success copy
# The project TreezRKool.sb3 has been success copy
# The project Tropho Farm.sb3 has been success copy
# The project Troubled Waters.sb3 has been success copy
# The project Truegreen7.sb3 has been success copy
# The project Untitled-2_(2).sb3 has been success copy
# The project Untitled-2_(3).sb3 has been success copy
# The project Untitled-3_(4).sb3 has been success copy
# The project Untitled_(2).sb3 has been success copy
# The project Unwanted Co2.sb3 has been success copy
# The project WACK-A-GAS.sb3 has been success copy
# The project Welcome to the Greenhouse.sb3 has been success copy
# The project World and Climate Changing Game.sb3 has been success copy
# The project World and Climate Changing Game_(2).sb3 has been success copy
# The project YOUNES AND MARAT QUIZ.sb3 has been success copy
# The project Yinyao Duan.sb3 has been success copy
# The project You Can Stop Climate Change One Shopping Trip At A Time!.sb3 doesnt exists
# The project Yuval and Rebecca Water cycle.sb3 has been success copy
# The project Zach Chase game.sb3 has been success copy
# The project Zach and Nico.sb3 has been success copy
# The project Zhimin and Isabella.sb3 has been success copy
# The project _.sb3 has been success copy
# The project `.sb3 has been success copy
# The project beat the heat.sb3 has been success copy
# The project catch the CO2 by Olivia and Polina.sb3 has been success copy
# The project climate change highway.sb3 has been success copy
# The project climate change pong.sb3 has been success copy
# The project climate change project finished.sb3 has been success copy
# The project co2 emmision game.sb3 has been success copy
# The project co2 game.sb3 has been success copy
# The project factory.sb3 has been success copy
# The project gobo global harm.sb3 has been success copy
# The project help the polar bear.sb3 has been success copy
# The project ice saver.sb3 has been success copy
# The project ice tray albedo edition.sb3 has been success copy
# The project jabby.sb3 has been success copy
# The project jumpy tree.sb3 has been success copy
# The project kill the CO2.sb3 has been success copy
# The project make the trees dissapear.sb3 has been success copy
# The project new maze.sb3 has been success copy
# The project planting trees game.sb3 has been success copy
# The project plants help the enviroment.sb3 has been success copy
# The project puffs of smoke.sb3 has been success copy
# The project sam.sb3 has been success copy
# The project scratch game Liz Ava.sb3 doesnt exists
# The project sean and josh.sb3 has been success copy
# The project trees and stuff.sb3 has been success copy
# The project trinity _ emma animation challenge.sb3 has been success copy
# The project welknkmCX 'lkSD ow EVIw oP iwb'lkNSFPVON.sb3 doesnt exists

# %%
def load_json_project(path_projectsb3):
    try:
        zip_file = ZipFile(path_projectsb3, "r")
        json_project = json.loads(zip_file.open("project.json").read())
        return json_project
    except BadZipFile:
        print('Bad zipfile')

def process(json_project):
    seq_num = 0
    dict_total_blocks = {}
    
    list_total_blocks = []

    for key, list_info in json_project.items():
        if key == "targets":
            for dict_target in list_info:
                target_name = dict_target.get('name')
                if target_name:
                    dict_total_blocks[target_name] = {}
                    dict_total_blocks[target_name][f'Seq_{seq_num}'] = []
                blocks = dict_target.get('blocks')
                if blocks:
                    for block_id, block_info in blocks.items():
                        if isinstance(block_info, dict):
                            topLevel = block_info.get('topLevel')
                            if topLevel:
                                seq_num += 1
                                dict_total_blocks[target_name][f'Seq_{seq_num}'] = []
                            opcode = block_info.get('opcode')
                            if opcode:
                                
                                dict_total_blocks[target_name][f'Seq_{seq_num}'].append(opcode)
                            list_total_blocks.append(block_info)
                            #dict_total_blocks[block_id] = block_info
    return dict_total_blocks

dict_total_blocks = {}
scripts = []
list_total_blocks = []
print(len(filenames_action))
for project in filenames_action:
    sb3_path = os.path.join('.','sb3_action_global',project)
    if os.path.isfile(sb3_path):
        print(project)
        json_project = load_json_project(sb3_path)
        dict_total_blocks = process(json_project)

        for sprite, seqs in dict_total_blocks.items():
            for idx, block_list in seqs.items():
                if block_list != []:
                    scripts.append(" ".join(block_list))

#print(dict_total_blocks)
for script in scripts:
    print(script + '\n')
# Out:
# 312
# Abby and Grace's project.sb3
# Adventures of TreeGuy.sb3
# Ahmet-Ofer.sb3
# Aji Jesu Game.sb3
# Albedo Barrier.sb3
# Albedo Pong.sb3
# Albedo Project.sb3
# Alex and Hannah's project.sb3
# Aman and Brady Project.sb3
# Anjali and Mariana-3.sb3
# Artem Tsukasa.sb3
# Atmosphere Pong.sb3
# Avery's Life.sb3
# Beat the Robot.sb3
# Becca and Alana Climate change.sb3
# Become the Best Lumberjack.sb3
# Brendan and Hallel.sb3
# Brick Breaker remix.sb3
# Bryan and Mark's Game Project.sb3
# Building wackamole in the city of Hainsboro.sb3
# CARbon Killer.sb3
# CAUSATION EVASION.sb3
# CO2 Crusher.sb3
# CO2 Drop.sb3
# CO2 Footprints.sb3
# CO2 Killer.sb3
# CO2 Stopper Copter.sb3
# CO2 Stopper.sb3
# CO2 destroyer.sb3
# CO2 fr.sb3
# CO2 journey.sb3
# Car Bike Atmosphere.sb3
# Car Game.sb3
# Car.sb3
# Carbon Annihilation.sb3
# Carbon Capture.sb3
# Carbon Clicker_(2).sb3
# Carbon Destroyer.sb3
# Carbon Footprint project.sb3
# Carbon Game by Ria and Sarah.sb3
# Carbon Game.sb3
# Carbon Maze.sb3
# Carbon Run.sb3
# Carbon Run_(2).sb3
# Cars and co2.sb3
# Catch the CO2.sb3
# Clara and Mira's Project.sb3
# Class Project Sage and Nora.sb3
# Click the cars!.sb3
# Climate Change - Caitlin & Irene.sb3
# Climate Change Catch Game.sb3
# Climate Change Choose Your Own Adventure.sb3
# Climate Change Game Hannah and Andrew.sb3
# Climate Change Game_(2).sb3
# Climate Change Game_(5).sb3
# Climate Change Game_(8).sb3
# Climate Change Game_(9).sb3
# Climate Change Mario.sb3
# Climate Change Pong Finished Version.sb3
# Climate Change Project: Saving the penguin.sb3
# Climate Change Project_(2).sb3
# Climate Change With Cars and CO2.sb3
# Climate Change and the CO2 Succa.sb3
# Climate Change project.sb3
# Climate Clikerz.sb3
# Climate Control.sb3
# Climate Control_(2).sb3
# Climate Jumper.sb3
# Climate Pong.sb3
# Climate change game!!!!.sb3
# Climate change game-jassec.sb3
# Climate change game.sb3
# Climate change- Emari Wakefield and Julia Machado.sb3
# Climate change.sb3
# Cloud Catching.sb3
# Co2 Catch.sb3
# Co2 Survival.sb3
# Cole and Ryan.sb3
# Collect Co2.sb3
# Collect the CO2.sb3
# Cool Climate Game.sb3
# Cow catch game.sb3
# Crab runner.sb3
# Crossing Guard of the Atmosphere.sb3
# Cut it out.sb3
# DO NOT PLAY THIS GAME. PLAY THE OTHER ONE!.sb3
# DON'T TOUCH THE WATER.sb3
# Daniel Scott.sb3
# Dat Albedo.sb3
# David & Peter.sb3
# Deforestation Disaster.sb3
# Deforestation Game.sb3
# Deforestation Game_(2).sb3
# Deforestation Hailey and Remi's Game.sb3
# Deforestation game.sb3
# Destroy the World.sb3
# Don't Get Burned!.sb3
# Dont Go With The Flow.sb3
# Dont break the ice remix emily and maddie.sb3
# ENOZO STOPPER.sb3
# ERIC AND ROSIE ANIMATION CHALLENGE.sb3
# Earth Vs Climate change Dodge ball game.sb3
# Earth vs. Floods.sb3
# Eat The Carbon by Barry and Kyrene.sb3
# Edie Bella Animation Challenge.sb3
# Ella and Arsema animation Challenge.sb3
# Ellie and Talia Untitled-5.sb3
# Elsa saves the world alebdo style.sb3
# Emily and haley Greenhouse effect.sb3
# Eujin and Julia.sb3
# Factory Game Thalia and Jehan.sb3
# Factory Game remix.sb3
# Factory Pollution.sb3
# FactorySimulator.sb3
# Falling Fruit Fiesta.sb3
# Farmer Sam and His Cows.sb3
# Fight Wanda the Evil Lumberjack.sb3
# Fight the Pollution!.sb3
# Flood the World.sb3
# Forest Fire Scratch Game Akash Adrien.sb3
# Forest.sb3
# Fortnite: Climate Change Edition.sb3
# Franki and Elena's game.sb3
# Future C02.sb3
# GHGs Game.sb3
# Gabe Umut-2.sb3
# Game John And Harry.sb3
# Garden Simulator 2k17.sb3
# Gil Avieli and Sam Atalla.sb3
# Global Warming Game.sb3
# Grayson Josh Animation Challenge.sb3
# Greenhouse Gases Game.sb3
# Guardian of the Forest.sb3
# Guy+Sonia-Lower the Carbon!.sb3
# Hagar and Sephora Reforestation.sb3
# Harrison And Constantinos.sb3
# Heat Havoc.sb3
# Heat absorber.sb3
# Hit the Target.sb3
# Hudson Animation Challenge.sb3
# Humanity vs Carbon vs Plants- Nolan and Chima.sb3
# Ice Blocker Climate Change Game.sb3
# Ice Cap Hero!.sb3
# Ice Pong.sb3
# Infrared Invasion.sb3
# Isabella and Sarah-3.sb3
# Island Fish Rescue.sb3
# IvGroup7s2 Max Dylan.sb3
# Jack and Zach's Epic Adventure.sb3
# JakeJaleikaAnimationChallenge.sb3
# Jocey and Natasha.sb3
# Joci and Becky Climate Change Games.sb3
# Joe and Aidan climate change slingshot thingy.sb3
# Joe and Charlie Final Project.sb3
# Julia and Meri's Game.sb3
# Jump Into Climate Change!.sb3
# KARINE AND LANCE.sb3
# Kendel and Ben's game.sb3
# Kenny Michael.sb3
# Kevin_Ben Animation Challenge.sb3
# Leaf Me Alone Carbon.com.net.org.io.exe.mp3.mp4.sb3
# Leyla and Erin-3 remix remix.sb3
# Log Samurai.sb3
# Lumberjack simulator.sb3
# Mark Jeremy.sb3
# Mitigation - Elias Daniel- F Block.sb3
# Mitigation Game.sb3
# Neo Jonathan.sb3
# New Science Scratch.sb3
# Nora + Sage.sb3
# Ocean Defender.sb3
# OliviaEmilyAnimaionChalllenge.sb3
# PONG CLIMATE CHANGE.sb3
# Patrick and Elaine.sb3
# Patrick and Sawyer Climate Game.sb3
# Penguin Game.sb3
# Penguin Saver- By Holland and Andrew.sb3
# Penguin game.sb3
# Picking Up Trash Helps The World: Mitigation.sb3
# Plant Man IV.sb3
# Plant the Trees!.sb3
# Polar Bear Fixes Climate Change.sb3
# Polar Saving.sb3
# Polluted Park.sb3
# Pollution Control.sb3
# Pollution Game.sb3
# Potato's adventure.sb3
# Preventing CO2 from coming into the Earth.sb3
# Preventing Greenhouse Gases With Paul the Poler Bear.sb3
# Rambunctious Recycling.sb3
# Reduce dat boi Co2 in the Atmosphere.sb3
# Reducing Meat Consumption.sb3
# Reducing Ocean Acidification.sb3
# Reforestation and Deforestation- Saving this land.sb3
# Rising Co2 Level.sb3
# Roberto and Ethan  -.sb3
# Ryan D and Weller B CC Game.sb3
# SOPHIA AND MADDIE.sb3
# STOP THOSE CARS!!!!!.sb3
# Sammie and Alex Carbon Cycle Project.sb3
# Sarita Gabe Game.sb3
# Save The Atmosphere.sb3
# Save The Fish.sb3
# Save The Ocean: A Crab Game.sb3
# Save The Trees_(3).sb3
# Save The World.sb3
# Save the Atmosphere!.sb3
# Save the Climate.sb3
# Save the Earth.sb3
# Save the Fishy.sb3
# Save the Oceans!.sb3
# Save the Planet!.sb3
# Save the Shellfish.sb3
# Save the Sky.sb3
# Save the Trees!.sb3
# Save the World from Co2!.sb3
# Save the penguin :).sb3
# Saving Squishy.sb3
# Saving The Earth One Seed At A Time.sb3
# Saving the Polar Bears.sb3
# Science Game.sb3
# Scratch CO2 Project.sb3
# Scratch Climate Change Project.sb3
# Scratch Project.sb3
# Scratch Project: Helen & Condoleezza.sb3
# Shayan and Jeff.sb3
# Sinking Penguin.sb3
# Soccer Pong.sb3
# Sofi S..sb3
# SofiaKevinAnimationChallenge.sb3
# Sophia and Mar Deforestation Game.sb3
# Sophie and Hannah's Climate Game!!!!!!!.sb3
# SophieDante Animation Challenge.sb3
# Space CO2.sb3
# Space Game 1: Climate Change.sb3
# Substantial Farming Simulator.sb3
# Sun Ray Shielder.sb3
# Super Carbon Bros.sb3
# Super Chad Bro..sb3
# Super Planty Bros (Drew and Sasha).sb3
# SuperSeaTurtleBro..sb3
# Sydney Forristall and Samuel Gordon.sb3
# Sydney _ Daniella game.sb3
# THE GLOBAL WARMING game!.sb3
# Take Action! - heymynamestrey.sb3
# Talia Celia.sb3
# Tesla CO2 Emissions.sb3
# The Awesome Lamp Game.sb3
# The Best Game You've Ever Played *No Guarentee.sb3
# The Carbon Challenge.sb3
# The Green House Game.sb3
# The Greenhouse Effect.sb3
# The Night sky.sb3
# The Polar Bear.sb3
# Transportation Pollution.sb3
# Tree Cutting Simulator.sb3
# Tree1 Climate Game.sb3
# Trees vs LumberJack.sb3
# TreezRKool.sb3
# Tropho Farm.sb3
# Troubled Waters.sb3
# Truegreen7.sb3
# Untitled-2_(2).sb3
# Untitled-2_(3).sb3
# Untitled-3_(4).sb3
# Untitled_(2).sb3
# Unwanted Co2.sb3
# WACK-A-GAS.sb3
# Welcome to the Greenhouse.sb3
# World and Climate Changing Game.sb3
# World and Climate Changing Game_(2).sb3
# YOUNES AND MARAT QUIZ.sb3
# Yinyao Duan.sb3
# Yuval and Rebecca Water cycle.sb3
# Zach Chase game.sb3
# Zach and Nico.sb3
# Zhimin and Isabella.sb3
# _.sb3
# `.sb3
# beat the heat.sb3
# catch the CO2 by Olivia and Polina.sb3
# climate change highway.sb3
# climate change pong.sb3
# climate change project finished.sb3
# co2 emmision game.sb3
# co2 game.sb3
# factory.sb3
# gobo global harm.sb3
# help the polar bear.sb3
# ice saver.sb3
# ice tray albedo edition.sb3
# jabby.sb3
# jumpy tree.sb3
# kill the CO2.sb3
# make the trees dissapear.sb3
# new maze.sb3
# planting trees game.sb3
# plants help the enviroment.sb3
# puffs of smoke.sb3
# sam.sb3
# sean and josh.sb3
# trees and stuff.sb3
# trinity _ emma animation challenge.sb3
# event_whenflagclicked data_showvariable data_setvariableto
#
# event_whenflagclicked data_showvariable data_setvariableto control_repeat_until operator_equals control_wait data_changevariableby sound_playuntildone sound_sounds_menu data_hidevariable data_hidevariable looks_switchbackdropto looks_backdrops
#
# event_whenbackdropswitchesto data_showvariable
#
# event_whenflagclicked control_forever sound_playuntildone sound_sounds_menu
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked looks_switchbackdropto looks_backdrops
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenflagclicked looks_switchbackdropto looks_backdrops
#
# event_whenbroadcastreceived looks_switchbackdropto looks_backdrops
#
# event_whenbroadcastreceived looks_switchbackdropto looks_backdrops
#
# event_whenflagclicked motion_gotoxy motion_setrotationstyle looks_show looks_setsizeto data_showvariable data_showvariable data_showvariable data_showvariable data_showvariable data_setvariableto data_setvariableto data_setvariableto data_setvariableto data_setvariableto data_setvariableto data_setvariableto control_forever data_setvariableto data_changevariableby data_changevariableby motion_changeyby procedures_call operator_gt
#
# event_whenflagclicked motion_pointindirection looks_sayforsecs operator_join operator_join sensing_username looks_sayforsecs looks_sayforsecs event_broadcast
#
# procedures_definition procedures_prototype control_if operator_not argument_reporter_boolean control_if sensing_touchingcolor control_if operator_equals data_changevariableby control_repeat looks_changeeffectby data_setvariableto motion_gotoxy control_repeat looks_changeeffectby control_if operator_equals data_changevariableby control_repeat looks_changeeffectby data_setvariableto motion_gotoxy control_repeat looks_changeeffectby control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby control_repeat looks_changeeffectby motion_pointindirection control_if operator_equals motion_gotoxy control_repeat looks_changeeffectby control_if operator_equals motion_gotoxy control_repeat looks_changeeffectby control_if operator_lt motion_yposition data_setvariableto data_changevariableby control_repeat looks_changeeffectby motion_pointindirection control_if operator_equals motion_gotoxy control_repeat looks_changeeffectby control_if sensing_touchingobject sensing_touchingobjectmenu data_setvariableto data_changevariableby control_if operator_equals control_repeat looks_changeeffectby motion_gotoxy motion_pointindirection control_repeat looks_changeeffectby control_if operator_equals control_repeat looks_changeeffectby motion_gotoxy motion_pointindirection control_repeat looks_changeeffectby control_wait control_if sensing_touchingobject sensing_touchingobjectmenu data_setvariableto data_changevariableby control_repeat looks_changeeffectby motion_gotoxy motion_pointindirection control_repeat looks_changeeffectby control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby data_setvariableto control_repeat looks_changeeffectby motion_gotoxy motion_pointindirection control_repeat looks_changeeffectby control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby data_setvariableto control_repeat looks_changeeffectby motion_gotoxy motion_pointindirection control_repeat looks_changeeffectby control_wait data_setvariableto
#
# procedures_definition procedures_prototype control_if operator_and sensing_keypressed sensing_keyoptions argument_reporter_boolean data_setvariableto
#
# procedures_definition procedures_prototype control_repeat_until operator_not operator_or sensing_touchingcolor sensing_touchingcolor control_if_else argument_reporter_boolean motion_changeyby motion_changeyby data_setvariableto data_setvariableto data_setvariableto procedures_call operator_and operator_equals operator_lt data_showvariable data_showvariable data_showvariable
#
# event_whenflagclicked control_wait_until operator_or operator_equals operator_gt looks_hide event_broadcast data_setvariableto data_hidevariable data_hidevariable data_hidevariable data_hidevariable data_hidevariable
#
# event_whenbroadcastreceived data_changevariableby looks_sayforsecs
#
# event_whenbroadcastreceived control_wait control_forever data_changevariableby control_wait
#
# event_whenbroadcastreceived looks_say looks_setsizeto motion_gotoxy data_hidevariable data_hidevariable data_hidevariable data_hidevariable data_hidevariable
#
# event_whenbroadcastreceived control_forever control_if sensing_keypressed sensing_keyoptions motion_pointindirection motion_changexby control_if sensing_touchingcolor motion_changexby control_if sensing_keypressed sensing_keyoptions motion_pointindirection motion_changexby control_if sensing_touchingcolor motion_changexby
#
# event_whenbroadcastreceived control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_sayforsecs control_wait_until operator_lt looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs event_broadcast
#
# event_whenbroadcastreceived control_forever data_setvariableto
#
# event_whenflagclicked control_forever control_if sensing_touchingcolor data_setvariableto control_if sensing_touchingobject sensing_touchingobjectmenu data_setvariableto control_if operator_lt motion_yposition data_setvariableto control_if sensing_touchingobject sensing_touchingobjectmenu data_setvariableto control_if sensing_touchingobject sensing_touchingobjectmenu data_setvariableto control_if sensing_touchingobject sensing_touchingobjectmenu data_setvariableto control_if sensing_touchingobject sensing_touchingobjectmenu data_setvariableto procedures_call operator_equals
#
# event_whenbroadcastreceived looks_sayforsecs looks_sayforsecs
#
# event_whenbroadcastreceived looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs
#
# event_whenbroadcastreceived control_forever control_if sensing_touchingobject sensing_touchingobjectmenu data_setvariableto data_changevariableby control_if operator_equals event_broadcast motion_gotoxy control_if operator_equals event_broadcast motion_gotoxy control_if operator_equals event_broadcast motion_gotoxy control_wait data_setvariableto
#
# event_whenbroadcastreceived control_forever control_if operator_gt motion_xposition motion_gotoxy motion_yposition control_if operator_gt motion_xposition motion_gotoxy motion_yposition argument_reporter_boolean argument_reporter_boolean argument_reporter_boolean
#
# event_whenflagclicked looks_show motion_gotoxy looks_switchcostumeto looks_costume control_forever control_if operator_equals control_if operator_gt looks_switchcostumeto looks_costume control_if operator_equals looks_switchcostumeto looks_costume control_if operator_lt looks_switchcostumeto looks_costume control_if operator_equals looks_switchcostumeto looks_costume control_if operator_equals looks_switchcostumeto looks_costume
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_setsizeto looks_hide
#
# event_whenflagclicked control_wait_until operator_equals control_create_clone_of control_create_clone_of_menu control_wait_until operator_equals control_create_clone_of control_create_clone_of_menu
#
# control_start_as_clone looks_show control_forever control_if operator_equals motion_glidesecstoxy motion_pointindirection motion_glidesecstoxy motion_pointindirection control_if operator_equals motion_gotoxy looks_setsizeto motion_glidesecstoxy motion_pointindirection motion_glidesecstoxy motion_pointindirection
#
# event_whenbroadcastreceived looks_hide
#
# control_start_as_clone control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide data_changevariableby control_if operator_equals control_wait_until operator_equals motion_xposition motion_gotoxy looks_show data_changevariableby control_if operator_equals control_wait_until operator_equals motion_xposition looks_show data_changevariableby
#
# motion_pointindirection
#
# control_start_as_clone control_forever control_if operator_equals control_wait_until operator_not operator_equals looks_hide
#
# control_start_as_clone control_forever control_if operator_equals looks_hide
#
# event_whenbroadcastreceived control_delete_this_clone
#
# event_whenflagclicked looks_show motion_gotoxy
#
# event_whenbroadcastreceived motion_gotoxy
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived motion_gotoxy
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked control_create_clone_of control_create_clone_of_menu control_wait_until operator_equals control_create_clone_of control_create_clone_of_menu control_wait_until operator_equals control_create_clone_of control_create_clone_of_menu control_wait_until operator_equals event_broadcast
#
# control_start_as_clone looks_show control_forever control_if operator_equals motion_gotoxy control_repeat_until operator_not operator_equals motion_glidesecstoxy motion_glidesecstoxy control_if operator_equals motion_gotoxy control_repeat_until operator_not operator_equals motion_glidesecstoxy motion_glidesecstoxy control_if operator_equals motion_gotoxy control_repeat_until operator_not operator_equals motion_glidesecstoxy motion_glidesecstoxy
#
# control_start_as_clone control_forever control_if sensing_touchingobject sensing_touchingobjectmenu control_wait data_changevariableby control_delete_this_clone
#
# control_if operator_equals motion_gotoxy control_repeat_until operator_not operator_equals motion_glidesecstoxy motion_glidesecstoxy control_if operator_equals motion_gotoxy control_repeat_until operator_not operator_equals motion_glidesecstoxy motion_glidesecstoxy
#
# control_if operator_equals motion_gotoxy control_repeat_until operator_not operator_equals motion_glidesecstoxy motion_glidesecstoxy control_if operator_equals motion_gotoxy control_repeat_until operator_not operator_equals motion_glidesecstoxy motion_glidesecstoxy
#
# event_whenflagclicked looks_hide
#
# control_start_as_clone control_forever control_if operator_equals control_wait_until operator_equals control_delete_this_clone
#
# event_whenbroadcastreceived control_forever motion_gotoxy operator_random operator_random control_if_else operator_not sensing_touchingobject sensing_touchingobjectmenu looks_show control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide data_changevariableby motion_gotoxy operator_random operator_random control_wait
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# control_start_as_clone control_forever control_if operator_equals control_wait_until operator_equals control_delete_this_clone
#
# event_whenflagclicked control_forever procedures_call operator_and operator_and operator_gt operator_equals operator_equals
#
# control_start_as_clone looks_show control_if_else operator_equals data_changevariableby data_changevariableby looks_show motion_gotoxy sensing_of sensing_of_object_menu operator_add sensing_of sensing_of_object_menu control_wait control_delete_this_clone data_changevariableby data_changevariableby looks_show motion_gotoxy sensing_of sensing_of_object_menu operator_add sensing_of sensing_of_object_menu control_wait_until operator_equals control_delete_this_clone
#
# event_whenflagclicked data_setvariableto looks_setsizeto looks_hide
#
# control_start_as_clone control_wait_until sensing_touchingobject sensing_touchingobjectmenu control_repeat looks_changeeffectby looks_hide
#
# procedures_definition procedures_prototype control_if operator_and sensing_keypressed sensing_keyoptions argument_reporter_boolean control_create_clone_of control_create_clone_of_menu data_changevariableby data_changevariableby control_if operator_equals data_setvariableto event_broadcast control_wait
#
# event_whenflagclicked looks_hide motion_pointindirection looks_setsizeto control_wait_until operator_equals control_create_clone_of control_create_clone_of_menu
#
# control_start_as_clone looks_show motion_gotoxy control_forever motion_glidesecstoxy motion_glidesecstoxy
#
# control_start_as_clone control_wait_until operator_not operator_equals control_delete_this_clone
#
# event_whenbroadcastreceived looks_hide
#
# control_start_as_clone control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide data_changevariableby control_wait_until operator_equals motion_yposition looks_show data_changevariableby
#
# event_whenflagclicked looks_hide motion_pointindirection looks_setsizeto control_wait_until operator_equals control_create_clone_of control_create_clone_of_menu
#
# control_start_as_clone looks_show motion_gotoxy control_forever motion_glidesecstoxy motion_glidesecstoxy
#
# control_start_as_clone control_if operator_equals control_wait_until operator_not operator_equals control_delete_this_clone
#
# operator_equals
#
# event_whenbroadcastreceived looks_hide
#
# control_start_as_clone control_wait_until operator_not operator_equals looks_hide
#
# control_start_as_clone control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide data_changevariableby control_wait_until operator_equals motion_yposition looks_show data_changevariableby
#
# event_whenflagclicked data_hidevariable looks_setsizeto motion_pointindirection looks_hide control_wait_until operator_equals looks_show data_showvariable data_setvariableto operator_round operator_divide motion_gotoxy control_forever motion_pointindirection motion_glidesecstoxy operator_random motion_pointindirection motion_glidesecstoxy operator_random
#
# event_whenbroadcastreceived sound_playuntildone sound_sounds_menu
#
# event_whenflagclicked control_forever control_if operator_and sensing_touchingobject sensing_touchingobjectmenu operator_equals data_changevariableby data_setvariableto control_if_else operator_equals data_setvariableto event_broadcast looks_hide control_repeat looks_changeeffectby control_repeat looks_changeeffectby data_setvariableto
#
# event_whenbroadcastreceived looks_hide data_hidevariable sound_playuntildone sound_sounds_menu
#
# event_whenflagclicked control_wait_until operator_equals control_wait control_repeat_until operator_equals control_wait event_broadcast data_changevariableby
#
# event_whenflagclicked looks_hide
#
# control_start_as_clone looks_setsizeto looks_show motion_gotoxy sensing_of sensing_of_object_menu sensing_of sensing_of_object_menu control_forever motion_turnright motion_changeyby
#
# control_start_as_clone control_wait_until operator_gt motion_yposition control_delete_this_clone
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived control_create_clone_of control_create_clone_of_menu
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_goforwardbackwardlayers looks_hide control_wait_until operator_equals looks_show motion_gotoxy control_wait_until operator_equals motion_gotoxy control_wait_until operator_equals looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_goforwardbackwardlayers looks_hide control_wait_until operator_equals looks_show motion_gotoxy control_wait_until operator_equals looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_goforwardbackwardlayers looks_hide control_wait_until operator_equals looks_show motion_gotoxy control_wait_until operator_equals looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_setsizeto looks_hide
#
# event_whenbroadcastreceived
#
# event_whenflagclicked motion_gotoxy control_wait looks_sayforsecs control_wait looks_sayforsecs
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# motion_gotoxy
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu data_changevariableby
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_wait_until
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# control_wait looks_show
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# looks_show
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# looks_show
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# looks_show
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked looks_hide
#
# event_whenflagclicked control_wait looks_sayforsecs control_wait looks_sayforsecs
#
# event_whenflagclicked motion_gotoxy
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy
#
# event_whenflagclicked control_wait_until sensing_touchingobject sensing_touchingobjectmenu looks_sayforsecs
#
# operator_not sensing_touchingobject sensing_touchingobjectmenu
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenflagclicked looks_switchbackdropto looks_backdrops
#
# event_whenkeypressed looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops
#
# event_whenbroadcastreceived looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops control_wait
#
# event_whenbackdropswitchesto data_setvariableto
#
# event_whenbroadcastreceived looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops control_wait
#
# control_wait
#
# event_whenflagclicked motion_gotoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy
#
# event_whenflagclicked control_forever control_wait control_create_clone_of control_create_clone_of_menu
#
# control_start_as_clone motion_gotoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# control_start_as_clone control_forever control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# event_whenflagclicked
#
# event_whenflagclicked data_setvariableto control_forever control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby control_if operator_equals event_broadcast
#
# event_whenflagclicked control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# event_whenbackdropswitchesto data_hidevariable
#
# event_whenbackdropswitchesto data_hidevariable
#
# event_whenbackdropswitchesto data_showvariable
#
# event_whenbackdropswitchesto data_showvariable
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbackdropswitchesto looks_show
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked data_setvariableto looks_hide
#
# event_whenbackdropswitchesto looks_show
#
# event_whenbroadcastreceived data_hidevariable
#
# event_whenbroadcastreceived data_hidevariable
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbroadcastreceived data_hidevariable
#
# event_whenflagclicked data_hidevariable
#
# event_whenbackdropswitchesto data_showvariable
#
# event_whenbackdropswitchesto control_forever control_wait data_changevariableby
#
# event_whenbackdropswitchesto data_setvariableto control_forever control_wait data_changevariableby
#
# event_whenflagclicked control_forever control_if operator_equals event_broadcast
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived data_hidevariable
#
# event_whenbroadcastreceived data_hidevariable
#
# event_whenbroadcastreceived data_hidevariable
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived
#
# event_whenkeypressed looks_show
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_show
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked control_forever control_if operator_lt data_setvariableto looks_sayforsecs event_broadcast
#
# music_playNoteForBeats note
#
# event_whenkeypressed
#
# music_playNoteForBeats note music_playNoteForBeats note
#
# music_restForBeats music_restForBeats music_restForBeats music_restForBeats music_restForBeats
#
# event_whenflagclicked
#
# music_playNoteForBeats note
#
# music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note
#
# event_whenflagclicked motion_glidesecstoxy
#
# ...
#
# event_whenflagclicked control_wait control_forever motion_movesteps control_if sensing_touchingobject sensing_touchingobjectmenu motion_ifonedgebounce
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked motion_gotoxy
#
# event_whenflagclicked control_wait control_repeat motion_changexby motion_gotoxy motion_changeyby
#
# event_whenflagclicked control_wait control_forever motion_movesteps control_if sensing_touchingobject sensing_touchingobjectmenu motion_ifonedgebounce
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked motion_gotoxy
#
# event_whenflagclicked control_wait control_repeat motion_changexby motion_gotoxy motion_changeyby
#
# event_whenflagclicked control_wait control_forever motion_movesteps control_if sensing_touchingobject sensing_touchingobjectmenu motion_ifonedgebounce
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked motion_gotoxy
#
# event_whenflagclicked control_wait control_repeat motion_changexby motion_gotoxy motion_changeyby
#
# event_whenflagclicked control_wait control_forever motion_movesteps control_if sensing_touchingobject sensing_touchingobjectmenu motion_ifonedgebounce
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked motion_gotoxy
#
# event_whenflagclicked control_wait control_repeat motion_changexby motion_gotoxy motion_changeyby
#
# event_whenflagclicked control_wait control_forever motion_movesteps control_if sensing_touchingobject sensing_touchingobjectmenu motion_ifonedgebounce
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked motion_gotoxy
#
# event_whenflagclicked control_wait control_repeat motion_changexby motion_gotoxy motion_changeyby
#
# event_whenflagclicked control_wait control_forever motion_movesteps control_if sensing_touchingobject sensing_touchingobjectmenu motion_ifonedgebounce
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked motion_gotoxy
#
# event_whenflagclicked control_wait control_repeat motion_changexby motion_gotoxy motion_changeyby
#
# event_whenflagclicked control_wait control_forever motion_movesteps control_if sensing_touchingobject sensing_touchingobjectmenu motion_ifonedgebounce
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked motion_gotoxy
#
# event_whenflagclicked control_wait control_repeat motion_changexby motion_gotoxy motion_changeyby
#
# event_whenflagclicked control_wait control_forever motion_movesteps control_if sensing_touchingobject sensing_touchingobjectmenu motion_ifonedgebounce
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked motion_gotoxy
#
# event_whenflagclicked control_wait control_repeat motion_changexby motion_gotoxy motion_changeyby
#
# event_whenflagclicked control_wait control_forever motion_movesteps control_if sensing_touchingobject sensing_touchingobjectmenu motion_ifonedgebounce
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked motion_gotoxy
#
# event_whenflagclicked control_wait control_repeat motion_changexby motion_gotoxy motion_changeyby
#
# event_whenflagclicked control_wait control_forever motion_movesteps control_if sensing_touchingobject sensing_touchingobjectmenu motion_ifonedgebounce
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked motion_gotoxy
#
# event_whenflagclicked control_wait control_repeat motion_changexby motion_gotoxy motion_changeyby
#
# event_whenflagclicked control_wait control_forever motion_movesteps control_if sensing_touchingobject sensing_touchingobjectmenu motion_ifonedgebounce
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked motion_gotoxy
#
# event_whenflagclicked control_wait control_repeat motion_changexby motion_gotoxy motion_changeyby
#
# event_whenflagclicked control_wait control_forever motion_movesteps control_if sensing_touchingobject sensing_touchingobjectmenu motion_ifonedgebounce
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked motion_gotoxy
#
# event_whenflagclicked control_wait control_repeat motion_changexby motion_gotoxy motion_changeyby
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingcolor looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingcolor looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingcolor looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingcolor looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingcolor looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingcolor looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingcolor looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked control_forever control_wait_until sensing_touchingcolor looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenbroadcastreceived looks_switchbackdropto looks_backdrops
#
# event_whenflagclicked looks_switchbackdropto looks_backdrops control_wait looks_switchbackdroptoandwait looks_backdrops event_broadcast
#
# event_whenbroadcastreceived control_forever looks_switchbackdropto looks_backdrops
#
# event_whenbroadcastreceived control_forever looks_switchbackdropto looks_backdrops
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_show motion_gotoxy control_forever control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_show
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_show
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_show
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_show
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_hide
#
# looks_show
#
# event_whenbroadcastreceived looks_show
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_hide
#
# looks_show
#
# event_whenbroadcastreceived looks_show
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_hide
#
# looks_show
#
# event_whenbroadcastreceived looks_show
#
# event_whenflagclicked looks_hide control_forever control_if sensing_touchingobject sensing_touchingobjectmenu event_broadcast looks_hide
#
# looks_show
#
# event_whenbroadcastreceived looks_show
#
# event_whenbroadcastreceived looks_show motion_gotoxy event_broadcast
#
# event_whenflagclicked looks_switchcostumeto looks_costume looks_hide
#
# event_whenkeypressed motion_changeyby
#
# event_whenkeypressed motion_changexby
#
# event_whenkeypressed motion_changexby
#
# event_whenflagclicked control_forever control_if sensing_touchingcolor motion_gotoxy
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu event_broadcast
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu event_broadcast
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu event_broadcast
#
# event_whenkeypressed motion_changeyby
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu event_broadcast
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenflagclicked control_forever control_if sensing_touchingcolor event_broadcast
#
# event_whenflagclicked control_forever control_if sensing_keypressed sensing_keyoptions motion_gotoxy
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_show
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenbroadcastreceived control_forever looks_show
#
# event_whenbroadcastreceived control_forever looks_show
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_show
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenbroadcastreceived control_forever looks_show
#
# event_whenbroadcastreceived control_forever looks_show
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_show
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenbroadcastreceived control_forever looks_show
#
# event_whenbroadcastreceived control_forever looks_show
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_show
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenbroadcastreceived control_forever looks_show
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu event_broadcast
#
# event_whenbroadcastreceived control_forever looks_show
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenbroadcastreceived control_forever looks_show
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide event_broadcast
#
# event_whenbroadcastreceived control_forever looks_hide
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_forever control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_and sensing_touchingobject sensing_touchingobjectmenu sensing_keypressed sensing_keyoptions looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_equals looks_hide
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_forever control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_and sensing_touchingobject sensing_touchingobjectmenu sensing_keypressed sensing_keyoptions looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_equals looks_hide
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_forever control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_and sensing_touchingobject sensing_touchingobjectmenu sensing_keypressed sensing_keyoptions looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_equals looks_hide
#
# event_whenflagclicked control_forever control_if operator_and sensing_touchingobject sensing_touchingobjectmenu sensing_keypressed sensing_keyoptions looks_switchcostumeto looks_costume
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_forever control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_equals looks_hide
#
# event_whenflagclicked control_forever control_if operator_and sensing_touchingobject sensing_touchingobjectmenu sensing_keypressed sensing_keyoptions looks_switchcostumeto looks_costume
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_forever control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_equals looks_hide
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_wait looks_switchcostumeto looks_costume
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_forever control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_and sensing_touchingobject sensing_touchingobjectmenu sensing_keypressed sensing_keyoptions looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_equals looks_hide
#
# event_whenflagclicked data_showvariable looks_switchbackdropto looks_backdrops looks_sayforsecs control_wait looks_sayforsecs control_wait looks_sayforsecs sensing_resettimer
#
# event_whenflagclicked data_setvariableto control_wait control_forever control_wait data_changevariableby
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenflagclicked data_setvariableto control_wait control_forever control_if sensing_keypressed sensing_keyoptions control_wait data_changevariableby
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenflagclicked control_forever control_if operator_equals data_hidevariable looks_switchbackdropto looks_backdrops looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs control_stop
#
# event_whenflagclicked looks_sayforsecs control_wait looks_sayforsecs control_wait sound_play sound_sounds_menu

# %% [markdown]
# ## CREATION OF DATASET

# %%
class SkipGramData(Dataset):
    def __init__(self, corpus, window_sz= 4):
        super().__init__
        self.corpus = corpus
        self.window = window_sz
        self.vocab = list(set(token.lower() for sentence in self.corpus for token in sentence.split())) # set elimina dups y no mantiene el orden
        self.word2idx = {word: idx for idx, word in enumerate(self.vocab)}
        self.idx2word = {idx: word for word, idx in self.word2idx.items()}
        self.data = self.gen_dataset()

    def gen_dataset(self):
        # Metod for enventanado
        data = []
        for sentence in self.corpus:
            text = sentence.lower().split()
            #print(text)
            for center_idx, center_word in enumerate(text):
                for offset in range(-self.window, self.window +1):
                    context_idx = center_idx + offset
                    if context_idx < 0 or context_idx >= len(text) or context_idx == center_idx: continue
                    context_word = text[context_idx]
                    data.append((self.word2idx[center_word], self.word2idx[context_word]))
        return data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

# %% [markdown]
# ## CREATION OF MODEL AND TRAINING FUNCTION

# %%
class SkipGram(nn.Module):
    def __init__(self, vocab_sz, embed_sz):
        super().__init__()
        self.embed_layer = nn.Linear(vocab_sz, embed_sz, bias = False)
        self.output_layer = nn.Linear(embed_sz, vocab_sz)

    def forward(self, x):
        return self.output_layer(self.embed_layer(x))

# %%
def train_skipgram(model, loss_function, optimizer, data_loader, epochs=100):
    model.train() 
    for epoch in range(epochs):
        total_loss = 0
        for center, context in data_loader:
            center, context = center.to(device), context.to(device)
            
            center_vector = torch.zeros(len(data_loader.dataset.vocab), device=device) 
            center_vector[center] = 1.0
            center_vector = center_vector.unsqueeze(0)  

            scores = model(center_vector)
            
            labels = torch.tensor([context], dtype=torch.long, device=device)
            loss = loss_function(scores, labels)
            
            # Backward pass y optimización
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            torch.cuda.synchronize() 
            
            # Acumulando la pérdida
            total_loss += loss.item()
        
        # Imprimir la pérdida media por epoch
        print(f'Epoch: {epoch+1}, Loss: {total_loss/len(data_loader)}')

# %% [markdown]
# ## TRAIN

# %%
learning_rate = 0.0001

dataset = SkipGramData(scripts)
print(type(dataset.data))
data_loader = DataLoader(dataset, batch_size=1, shuffle=True)
model = SkipGram(len(dataset.vocab), embed_sz=300).to(device)
optimizer = optim.Adam(model.parameters(), lr= learning_rate)
loss_function = nn.CrossEntropyLoss()

train_skipgram(model, loss_function, optimizer, data_loader, epochs=10)
#for center_idx, context_idx in dataset.data:
    #print(dataset.idx2word[center_idx],dataset.idx2word[context_idx])
# Out:
# <class 'list'>
# Epoch: 1, Loss: 3.422975775254303
# Epoch: 2, Loss: 3.3785443652330778
# Epoch: 3, Loss: 3.37718214654939
# Epoch: 4, Loss: 3.3778514574513645
# Epoch: 5, Loss: 3.378795350750462
# Epoch: 6, Loss: 3.380670312603721
# Epoch: 7, Loss: 3.3825327539451506
# Epoch: 8, Loss: 3.3849029864564724
# Epoch: 9, Loss: 3.3858635896220832
# Epoch: 10, Loss: 3.3864994266354427

# %% [markdown]
# ## PLOTING RESULTS

# %%
def plot_embeddings(embedings, word2idx):
    num_samples = len(word2idx)
    tsne = TSNE(n_components=2, random_state=0)
    vectors = tsne.fit_transform(embeddings)
    plt.figure(figsize=(30,20))
    for word, idx in word2idx.items():
        plt.scatter(vectors[idx, 0], vectors[idx, 1])
        plt.annotate(word, xy=(vectors[idx, 0], vectors[idx, 1]), xytext=(5,2), 
                    textcoords='offset points', ha='right', va='bottom')
    plt.title('Word Embeddings Visualized using t-SNE')
    plt.xlabel('t-SNE Dimension 1')
    plt.ylabel(True)
    plt.savefig('embedding_action_global_wsz4.png', format='png')
    plt.show()

# %%
embeddings = model.embed_layer.weight.detach().cpu().numpy()
plot_embeddings(embeddings, dataset.word2idx)

# %% [markdown]
# ## MODEL SAVING

# %%
# Save trained model
model_path = "embedding_action_global_wsz4.pth"
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict()
}, model_path)

# %%
print("Dispositivo del modelo:", next(model.parameters()).device)
# Out:
# Dispositivo del modelo: cuda:0

# %% [markdown]
# ### Apply K-Means

# %%
# Configurar el número de clusters
n_clusters = 10

# Aplicar K-means
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(embeddings)
labels = kmeans.labels_

# %%
# Reducir los embeddings a 2D usando t-SNE
tsne = TSNE(n_components=2, random_state=0)
embeddings_2d = tsne.fit_transform(embeddings)

# Crear un mapa de colores para los clusters
colors = plt.cm.rainbow(np.linspace(0, 1, n_clusters))

# Plotear los embeddings
plt.figure(figsize=(10, 10))
for i in range(n_clusters):
    points = embeddings_2d[labels == i]
    plt.scatter(points[:, 0], points[:, 1], color=colors[i], label=f'Cluster {i}')
plt.legend()
plt.title('Embeddings clustered with K-means')
plt.xlabel('Dimension 1')
plt.ylabel('Dimension 2')
plt.show()

# %% [markdown]
# ## K-Means and Embeddings Graph (NOT NECESSARY EXECUTE THE CODE ABOVE)

# %%
import matplotlib.cm as cm
print(embeddings)
def plot_embeddings(embeddings, word2idx, n_clusters=10):
    num_samples = len(word2idx)

    # Realizar K-means clustering
    kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(embeddings)
    labels = kmeans.labels_

    # Reducir dimensionalidad con t-SNE
    tsne = TSNE(n_components=2, random_state=0)
    vectors = tsne.fit_transform(embeddings)

    # Crear un mapa de colores para los clusters
    colors = cm.rainbow(np.linspace(0, 1, n_clusters))

    plt.figure(figsize=(30, 20))
    
    # Dibujar los puntos con los colores de los clusters
    for i, (word, idx) in enumerate(word2idx.items()):
        cluster_id = labels[idx]
        plt.scatter(vectors[idx, 0], vectors[idx, 1], color=colors[cluster_id], label=f'Cluster {cluster_id}' if i == 0 else "")

    # Añadir anotaciones de las palabras
    for word, idx in word2idx.items():
        plt.annotate(word, xy=(vectors[idx, 0], vectors[idx, 1]), xytext=(5, 2),
                     textcoords='offset points', ha='right', va='bottom')
    
    plt.title('Word Embeddings Visualized using t-SNE and Clustered with K-means')
    plt.xlabel('t-SNE Dimension 1')
    plt.ylabel('t-SNE Dimension 2')
    plt.savefig('embedding_action_pong.png', format='png')
    plt.show()
plot_embeddings(embeddings, dataset.word2idx)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 import matplotlib.cm as cm
# ----> 2 print(embeddings)
#       3 def plot_embeddings(embeddings, word2idx, n_clusters=10):
#       4     num_samples = len(word2idx)
#
# NameError: name 'embeddings' is not defined
