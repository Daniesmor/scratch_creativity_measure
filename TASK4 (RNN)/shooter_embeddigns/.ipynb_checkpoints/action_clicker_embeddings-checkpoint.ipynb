# %% [markdown]
# # BUILDING OF EMBEDDINGS FOR **ACTION CLICKER**

# %%
import pandas as pd
import os
import shutil
from zipfile import ZipFile, BadZipFile
import json
import numpy as np
from torch.cuda.amp import GradScaler, autocast


import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

print(np.__version__)
# Out:
# 1.26.4

# %% [markdown]
# ## USE GPU

# %%
def check_gpu():
    if torch.cuda.is_available():
        print("CUDA está disponible.")
        print(f"Hay {torch.cuda.device_count()} GPU(s) disponible(s).")
        for i in range(torch.cuda.device_count()):
            print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
    else:
        print("CUDA no está disponible. No hay GPU accesible.")

check_gpu()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# CUDA está disponible.
# Hay 1 GPU(s) disponible(s).
# GPU 0: NVIDIA GeForce RTX 2060

# %% [markdown]
# ## DATA PREPROCESSING: Creation of scripts list with all project scripts

# %%
metrics = pd.read_csv('metrics_attr.csv')

# Filter by Action Genre
metrics_action_clicker = metrics[(metrics['Main Genre'] == 'Action') & (metrics['Second Genre']== 'Clicker')]

# Check the filenames for collect
filenames_action_clicker = list(metrics_action_clicker['Name'])
print(filenames_action_clicker)
# Create txt for made the shell script
with open('filenames_action_clicker.txt', 'w') as names_clicker:
     for name in filenames_action_clicker:
        names_clicker.write(name + '\n')


for project in filenames_action_clicker:
    sb3_path = f'./projects_sb3/{project}'
    if os.path.isfile(sb3_path):
        shutil.copy(sb3_path, './sb3_action_clicker')
        print(f'The project {project} has been success copy')
    else:
        print(f'The project {project} doesnt exists')
# Out:
# ["Abby and Grace's project.sb3", 'Aji Jesu Game.sb3', 'Becca and Alana Climate change.sb3', 'Brendan and Hallel.sb3', 'Building wackamole in the city of Hainsboro.sb3', 'CARBON CLICKING (Arjun the other one was screwed up so I made a new one).sb3', 'CARbon Killer.sb3', 'CO2 Crusher.sb3', 'CO2 Killer.sb3', 'CO2 fr.sb3', 'Car.sb3', 'Carbon Clicker_(2).sb3', 'Carbon Destroyer.sb3', 'Carbon Footprint project.sb3', 'Catch the CO2.sb3', "Clara and Mira's Project.sb3", 'Class Project Sage and Nora.sb3', 'Climate Change - Caitlin & Irene.sb3', 'Climate Change Game_(9).sb3', 'Climate Change Project_(2).sb3', 'Climate Change With Cars and CO2.sb3', 'Climate Change and the CO2 Succa.sb3', 'Climate Clikerz.sb3', 'Climate Control.sb3', 'Climate change game!!!!.sb3', 'Climate change game.sb3', 'Climate change.sb3', 'Co2 Survival.sb3', 'David & Peter.sb3', 'Deforestation Game.sb3', "Don't Get Burned!.sb3", 'Emily and haley Greenhouse effect.sb3', 'Eujin and Julia.sb3', 'Factory Game Thalia and Jehan.sb3', 'Factory Game remix.sb3', 'Farmer Sam and His Cows.sb3', 'Future C02.sb3', 'Garden Simulator 2k17.sb3', 'Global Warming Game.sb3', 'Greenhouse Gases Game.sb3', 'Guy+Sonia-Lower the Carbon!.sb3', 'Hagar and Sephora Reforestation.sb3', 'Jocey and Natasha.sb3', 'Joe and Aidan climate change slingshot thingy.sb3', "Kendel and Ben's game.sb3", 'Latifah M.Sophie N.Ava M..sb3', 'Leaf Me Alone Carbon.com.net.org.io.exe.mp3.mp4.sb3', 'Log Samurai.sb3', 'Lumberjack simulator.sb3', 'Mark Jeremy.sb3', 'Mitigation Game.sb3', 'Neo Jonathan.sb3', 'Ocean Defender.sb3', 'Penguin game.sb3', 'Picking Up Trash Helps The World: Mitigation.sb3', 'Plant the Trees!.sb3', 'Preventing Greenhouse Gases With Paul the Poler Bear.sb3', 'STOP THOSE CARS!!!!!.sb3', 'Save The Fish.sb3', 'Save The Trees_(3).sb3', 'Save the Oceans!.sb3', 'Save the World from Co2!.sb3', 'Saving Squishy.sb3', 'Saving The Earth One Seed At A Time.sb3', 'Scratch CO2 Project.sb3', 'Scratch Climate Change Project.sb3', 'Scratch Project.sb3', 'Scratch Project: Helen & Condoleezza.sb3', 'Sophia and Mar Deforestation Game.sb3', 'Space CO2.sb3', 'Sydney _ Daniella game.sb3', 'The Awesome Lamp Game.sb3', "The Best Game You've Ever Played *No Guarentee.sb3", 'The Night sky.sb3', 'Tree Cutting Simulator.sb3', 'Tree1 Climate Game.sb3', 'Tropho Farm.sb3', 'Untitled-2_(3).sb3', 'WACK-A-GAS.sb3', 'World and Climate Changing Game.sb3', 'World and Climate Changing Game_(2).sb3', 'Zach Chase game.sb3', 'co2 emmision game.sb3', 'co2 game.sb3', 'gobo global harm.sb3', 'planting trees game.sb3', 'puffs of smoke.sb3', 'trees and stuff.sb3']
# The project Abby and Grace's project.sb3 has been success copy
# The project Aji Jesu Game.sb3 has been success copy
# The project Becca and Alana Climate change.sb3 has been success copy
# The project Brendan and Hallel.sb3 has been success copy
# The project Building wackamole in the city of Hainsboro.sb3 has been success copy
# The project CARBON CLICKING (Arjun the other one was screwed up so I made a new one).sb3 doesnt exists
# The project CARbon Killer.sb3 has been success copy
# The project CO2 Crusher.sb3 has been success copy
# The project CO2 Killer.sb3 has been success copy
# The project CO2 fr.sb3 has been success copy
# The project Car.sb3 has been success copy
# The project Carbon Clicker_(2).sb3 has been success copy
# The project Carbon Destroyer.sb3 has been success copy
# The project Carbon Footprint project.sb3 has been success copy
# The project Catch the CO2.sb3 has been success copy
# The project Clara and Mira's Project.sb3 has been success copy
# The project Class Project Sage and Nora.sb3 has been success copy
# The project Climate Change - Caitlin & Irene.sb3 has been success copy
# The project Climate Change Game_(9).sb3 has been success copy
# The project Climate Change Project_(2).sb3 has been success copy
# The project Climate Change With Cars and CO2.sb3 has been success copy
# The project Climate Change and the CO2 Succa.sb3 has been success copy
# The project Climate Clikerz.sb3 has been success copy
# The project Climate Control.sb3 has been success copy
# The project Climate change game!!!!.sb3 has been success copy
# The project Climate change game.sb3 has been success copy
# The project Climate change.sb3 has been success copy
# The project Co2 Survival.sb3 has been success copy
# The project David & Peter.sb3 has been success copy
# The project Deforestation Game.sb3 has been success copy
# The project Don't Get Burned!.sb3 has been success copy
# The project Emily and haley Greenhouse effect.sb3 has been success copy
# The project Eujin and Julia.sb3 has been success copy
# The project Factory Game Thalia and Jehan.sb3 has been success copy
# The project Factory Game remix.sb3 has been success copy
# The project Farmer Sam and His Cows.sb3 has been success copy
# The project Future C02.sb3 has been success copy
# The project Garden Simulator 2k17.sb3 has been success copy
# The project Global Warming Game.sb3 has been success copy
# The project Greenhouse Gases Game.sb3 has been success copy
# The project Guy+Sonia-Lower the Carbon!.sb3 has been success copy
# The project Hagar and Sephora Reforestation.sb3 has been success copy
# The project Jocey and Natasha.sb3 has been success copy
# The project Joe and Aidan climate change slingshot thingy.sb3 has been success copy
# The project Kendel and Ben's game.sb3 has been success copy
# The project Latifah M.Sophie N.Ava M..sb3 doesnt exists
# The project Leaf Me Alone Carbon.com.net.org.io.exe.mp3.mp4.sb3 has been success copy
# The project Log Samurai.sb3 has been success copy
# The project Lumberjack simulator.sb3 has been success copy
# The project Mark Jeremy.sb3 has been success copy
# The project Mitigation Game.sb3 has been success copy
# The project Neo Jonathan.sb3 has been success copy
# The project Ocean Defender.sb3 has been success copy
# The project Penguin game.sb3 has been success copy
# The project Picking Up Trash Helps The World: Mitigation.sb3 has been success copy
# The project Plant the Trees!.sb3 has been success copy
# The project Preventing Greenhouse Gases With Paul the Poler Bear.sb3 has been success copy
# The project STOP THOSE CARS!!!!!.sb3 has been success copy
# The project Save The Fish.sb3 has been success copy
# The project Save The Trees_(3).sb3 has been success copy
# The project Save the Oceans!.sb3 has been success copy
# The project Save the World from Co2!.sb3 has been success copy
# The project Saving Squishy.sb3 has been success copy
# The project Saving The Earth One Seed At A Time.sb3 has been success copy
# The project Scratch CO2 Project.sb3 has been success copy
# The project Scratch Climate Change Project.sb3 has been success copy
# The project Scratch Project.sb3 has been success copy
# The project Scratch Project: Helen & Condoleezza.sb3 has been success copy
# The project Sophia and Mar Deforestation Game.sb3 has been success copy
# The project Space CO2.sb3 has been success copy
# The project Sydney _ Daniella game.sb3 has been success copy
# The project The Awesome Lamp Game.sb3 has been success copy
# The project The Best Game You've Ever Played *No Guarentee.sb3 has been success copy
# The project The Night sky.sb3 has been success copy
# The project Tree Cutting Simulator.sb3 has been success copy
# The project Tree1 Climate Game.sb3 has been success copy
# The project Tropho Farm.sb3 has been success copy
# The project Untitled-2_(3).sb3 has been success copy
# The project WACK-A-GAS.sb3 has been success copy
# The project World and Climate Changing Game.sb3 has been success copy
# The project World and Climate Changing Game_(2).sb3 has been success copy
# The project Zach Chase game.sb3 has been success copy
# The project co2 emmision game.sb3 has been success copy
# The project co2 game.sb3 has been success copy
# The project gobo global harm.sb3 has been success copy
# The project planting trees game.sb3 has been success copy
# The project puffs of smoke.sb3 has been success copy
# The project trees and stuff.sb3 has been success copy

# %%
def load_json_project(path_projectsb3):
    try:
        zip_file = ZipFile(path_projectsb3, "r")
        json_project = json.loads(zip_file.open("project.json").read())
        return json_project
    except BadZipFile:
        print('Bad zipfile')

def process(json_project):
    seq_num = 0
    dict_total_blocks = {}
    
    list_total_blocks = []

    for key, list_info in json_project.items():
        if key == "targets":
            for dict_target in list_info:
                target_name = dict_target.get('name')
                if target_name:
                    dict_total_blocks[target_name] = {}
                    dict_total_blocks[target_name][f'Seq_{seq_num}'] = []
                blocks = dict_target.get('blocks')
                if blocks:
                    for block_id, block_info in blocks.items():
                        if isinstance(block_info, dict):
                            topLevel = block_info.get('topLevel')
                            if topLevel:
                                seq_num += 1
                                dict_total_blocks[target_name][f'Seq_{seq_num}'] = []
                            opcode = block_info.get('opcode')
                            if opcode:
                                
                                dict_total_blocks[target_name][f'Seq_{seq_num}'].append(opcode)
                            list_total_blocks.append(block_info)
                            #dict_total_blocks[block_id] = block_info
    return dict_total_blocks

dict_total_blocks = {}
scripts = []
list_total_blocks = []
print(len(filenames_action_clicker))
for project in filenames_action_clicker:
    sb3_path = os.path.join('.','sb3_action_clicker',project)
    if os.path.isfile(sb3_path):
        print(project)
        json_project = load_json_project(sb3_path)
        dict_total_blocks = process(json_project)

        for sprite, seqs in dict_total_blocks.items():
            for idx, block_list in seqs.items():
                if block_list != []:
                    scripts.append(" ".join(block_list))

#print(scripts)
for script in scripts:
    print(script + '\n')
# Out:
# 88
# Abby and Grace's project.sb3
# Aji Jesu Game.sb3
# Becca and Alana Climate change.sb3
# Brendan and Hallel.sb3
# Building wackamole in the city of Hainsboro.sb3
# CARbon Killer.sb3
# CO2 Crusher.sb3
# CO2 Killer.sb3
# CO2 fr.sb3
# Car.sb3
# Carbon Clicker_(2).sb3
# Carbon Destroyer.sb3
# Carbon Footprint project.sb3
# Catch the CO2.sb3
# Clara and Mira's Project.sb3
# Class Project Sage and Nora.sb3
# Climate Change - Caitlin & Irene.sb3
# Climate Change Game_(9).sb3
# Climate Change Project_(2).sb3
# Climate Change With Cars and CO2.sb3
# Climate Change and the CO2 Succa.sb3
# Climate Clikerz.sb3
# Climate Control.sb3
# Climate change game!!!!.sb3
# Climate change game.sb3
# Climate change.sb3
# Co2 Survival.sb3
# David & Peter.sb3
# Deforestation Game.sb3
# Don't Get Burned!.sb3
# Emily and haley Greenhouse effect.sb3
# Eujin and Julia.sb3
# Factory Game Thalia and Jehan.sb3
# Factory Game remix.sb3
# Farmer Sam and His Cows.sb3
# Future C02.sb3
# Garden Simulator 2k17.sb3
# Global Warming Game.sb3
# Greenhouse Gases Game.sb3
# Guy+Sonia-Lower the Carbon!.sb3
# Hagar and Sephora Reforestation.sb3
# Jocey and Natasha.sb3
# Joe and Aidan climate change slingshot thingy.sb3
# Kendel and Ben's game.sb3
# Leaf Me Alone Carbon.com.net.org.io.exe.mp3.mp4.sb3
# Log Samurai.sb3
# Lumberjack simulator.sb3
# Mark Jeremy.sb3
# Mitigation Game.sb3
# Neo Jonathan.sb3
# Ocean Defender.sb3
# Penguin game.sb3
# Picking Up Trash Helps The World: Mitigation.sb3
# Plant the Trees!.sb3
# Preventing Greenhouse Gases With Paul the Poler Bear.sb3
# STOP THOSE CARS!!!!!.sb3
# Save The Fish.sb3
# Save The Trees_(3).sb3
# Save the Oceans!.sb3
# Save the World from Co2!.sb3
# Saving Squishy.sb3
# Saving The Earth One Seed At A Time.sb3
# Scratch CO2 Project.sb3
# Scratch Climate Change Project.sb3
# Scratch Project.sb3
# Scratch Project: Helen & Condoleezza.sb3
# Sophia and Mar Deforestation Game.sb3
# Space CO2.sb3
# Sydney _ Daniella game.sb3
# The Awesome Lamp Game.sb3
# The Best Game You've Ever Played *No Guarentee.sb3
# The Night sky.sb3
# Tree Cutting Simulator.sb3
# Tree1 Climate Game.sb3
# Tropho Farm.sb3
# Untitled-2_(3).sb3
# WACK-A-GAS.sb3
# World and Climate Changing Game.sb3
# World and Climate Changing Game_(2).sb3
# Zach Chase game.sb3
# co2 emmision game.sb3
# co2 game.sb3
# gobo global harm.sb3
# planting trees game.sb3
# puffs of smoke.sb3
# trees and stuff.sb3
# event_whenflagclicked data_showvariable data_setvariableto
#
# event_whenflagclicked data_showvariable data_setvariableto control_repeat_until operator_equals control_wait data_changevariableby sound_playuntildone sound_sounds_menu data_hidevariable data_hidevariable looks_switchbackdropto looks_backdrops
#
# event_whenbackdropswitchesto data_showvariable
#
# event_whenflagclicked control_forever sound_playuntildone sound_sounds_menu
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked looks_switchbackdropto looks_backdrops
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenflagclicked control_forever control_wait looks_show motion_gotoxy motion_glidesecstoxy looks_hide control_wait
#
# event_whenbackdropswitchesto control_forever looks_hide
#
# event_whenthisspriteclicked looks_hide sound_play sound_sounds_menu data_changevariableby
#
# event_whenflagclicked looks_switchbackdropto looks_backdrops
#
# event_whenkeypressed looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops
#
# event_whenbroadcastreceived looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops control_wait
#
# event_whenbackdropswitchesto data_setvariableto
#
# event_whenbroadcastreceived looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops control_wait
#
# control_wait
#
# event_whenflagclicked motion_gotoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy
#
# event_whenflagclicked control_forever control_wait control_create_clone_of control_create_clone_of_menu
#
# control_start_as_clone motion_gotoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# control_start_as_clone control_forever control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# event_whenflagclicked
#
# event_whenflagclicked data_setvariableto control_forever control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby control_if operator_equals event_broadcast
#
# event_whenflagclicked control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# event_whenbackdropswitchesto data_hidevariable
#
# event_whenbackdropswitchesto data_hidevariable
#
# event_whenbackdropswitchesto data_showvariable
#
# event_whenbackdropswitchesto data_showvariable
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbackdropswitchesto looks_show
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked data_setvariableto looks_hide
#
# event_whenbackdropswitchesto looks_show
#
# event_whenbroadcastreceived data_hidevariable
#
# event_whenbroadcastreceived data_hidevariable
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbroadcastreceived data_hidevariable
#
# event_whenflagclicked data_hidevariable
#
# event_whenbackdropswitchesto data_showvariable
#
# event_whenbackdropswitchesto control_forever control_wait data_changevariableby
#
# event_whenbackdropswitchesto data_setvariableto control_forever control_wait data_changevariableby
#
# event_whenflagclicked control_forever control_if operator_equals event_broadcast
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived data_hidevariable
#
# event_whenbroadcastreceived data_hidevariable
#
# event_whenbroadcastreceived data_hidevariable
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived
#
# event_whenkeypressed looks_show
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_show
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked control_forever control_if operator_lt data_setvariableto looks_sayforsecs event_broadcast
#
# music_playNoteForBeats note
#
# event_whenkeypressed
#
# music_playNoteForBeats note music_playNoteForBeats note
#
# music_restForBeats music_restForBeats music_restForBeats music_restForBeats music_restForBeats
#
# event_whenflagclicked
#
# music_playNoteForBeats note
#
# music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note
#
# event_whenflagclicked motion_glidesecstoxy
#
# event_whenkeypressed music_setInstrument music_menu_INSTRUMENT music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note control_wait music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_setInstrument music_menu_INSTRUMENT music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note
#
# event_whenkeypressed music_setInstrument music_menu_INSTRUMENT music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note control_repeat music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note
#
# event_whenkeypressed music_setInstrument music_menu_INSTRUMENT music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note control_repeat music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_restForBeats music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note music_restForBeats
#
# event_whenflagclicked music_playNoteForBeats note music_playNoteForBeats note music_playNoteForBeats note control_wait music_playNoteForBeats note control_wait music_playNoteForBeats note control_wait
#
# event_whenflagclicked looks_hide
#
# event_whenflagclicked motion_gotoxy motion_glidesecstoxy control_forever control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# event_whenkeypressed
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy looks_hide
#
# control_create_clone_of control_create_clone_of_menu control_repeat motion_gotoxy motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide looks_show
#
# event_whenbroadcastreceived control_if_else operator_equals control_forever motion_gotoxy looks_hide data_changevariableby looks_show motion_gotoxy motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy looks_hide
#
# data_changevariableby
#
# event_whenflagclicked looks_hide
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_hide motion_gotoxy
#
# event_whenflagclicked data_setvariableto control_forever control_if operator_equals looks_hide
#
# event_whenkeypressed data_changevariableby looks_show motion_gotoxy motion_glidesecstoxy operator_random control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_hide
#
# control_wait control_create_clone_of control_create_clone_of_menu
#
# event_whenflagclicked
#
# event_whenbackdropswitchesto control_forever motion_gotoxy looks_hide
#
# event_whenbackdropswitchesto looks_show
#
# event_whenbackdropswitchesto control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_gotoxy
#
# event_whenbackdropswitchesto control_repeat control_forever control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# event_whenbackdropswitchesto
#
# event_whenbackdropswitchesto control_forever control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# control_start_as_clone control_forever control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# control_start_as_clone control_forever motion_gotoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy motion_glidesecstoxy
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto control_forever control_wait control_create_clone_of control_create_clone_of_menu
#
# event_whenkeypressed control_repeat control_forever control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# control_start_as_clone control_forever control_if sensing_touchingobject sensing_touchingobjectmenu control_forever motion_gotoxy looks_hide
#
# control_start_as_clone control_forever control_if sensing_touchingobject sensing_touchingobjectmenu
#
# control_start_as_clone looks_show control_forever control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby control_if operator_equals event_broadcast
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby control_if operator_equals event_broadcast
#
# control_start_as_clone control_forever control_if sensing_touchingobject sensing_touchingobjectmenu control_wait motion_gotoxy looks_hide
#
# event_whenkeypressed
#
# control_start_as_clone control_if sensing_keypressed sensing_keyoptions control_if operator_gt control_stop
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_sayforsecs event_broadcast
#
# event_whenflagclicked looks_hide
#
# event_whenbackdropswitchesto motion_gotoxy looks_show
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenkeypressed
#
# event_whenbackdropswitchesto looks_show
#
# event_whenbroadcastreceived looks_hide
#
# event_whenkeypressed data_changevariableby
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenkeypressed
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenkeypressed looks_show
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbackdropswitchesto looks_show
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenkeypressed looks_show
#
# event_whenbroadcastreceived looks_hide
#
# control_create_clone_of control_create_clone_of_menu
#
# event_whenflagclicked data_setvariableto control_forever control_if operator_equals looks_hide
#
# event_whenflagclicked control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy looks_hide
#
# event_whenbroadcastreceived control_if_else operator_equals control_forever motion_gotoxy looks_hide data_changevariableby looks_show motion_gotoxy motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy looks_hide
#
# control_repeat motion_gotoxy motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide looks_show
#
# event_whenkeypressed data_changevariableby looks_show motion_gotoxy motion_glidesecstoxy operator_random control_if sensing_touchingobject sensing_touchingobjectmenu motion_gotoxy looks_hide
#
# event_whenflagclicked control_forever control_if operator_equals data_setvariableto looks_hide motion_gotoxy
#
# event_whenflagclicked
#
# event_whenkeypressed control_forever control_if operator_equals data_setvariableto looks_hide motion_gotoxy
#
# control_if
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenkeypressed
#
# event_whenkeypressed data_changevariableby looks_show motion_gotoxy motion_glidesecstoxy operator_random control_repeat motion_ifonedgebounce motion_glidesecstoxy operator_random operator_random motion_gotoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto motion_gotoxy looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenthisspriteclicked looks_switchbackdropto looks_backdrops
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbackdropswitchesto looks_show
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenflagclicked control_if operator_gt data_setvariableto
#
# event_whenbroadcastreceived looks_hide
#
# event_whenbackdropswitchesto control_wait looks_show motion_gotoxy
#
# event_whenbackdropswitchesto control_wait data_setvariableto sensing_timer data_setvariableto data_setvariableto control_repeat control_wait data_changevariableby control_if operator_lt looks_switchbackdroptoandwait looks_backdrops control_if operator_or operator_equals operator_gt looks_switchbackdropto looks_backdrops
#
# event_whenkeypressed looks_switchbackdropto looks_backdrops
#
# event_whenflagclicked control_wait
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenbackdropswitchesto control_wait motion_gotoxy looks_show motion_glidesecstoxy looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenthisspriteclicked data_changevariableby looks_hide
#
# event_whenflagclicked looks_show control_wait looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs control_wait looks_sayforsecs looks_sayforsecs looks_sayforsecs
#
# event_whenbackdropswitchesto looks_hide
#
# event_whenflagclicked looks_switchbackdropto looks_backdrops
#
# event_whenkeypressed control_wait_until operator_equals looks_switchbackdropto looks_backdrops
#
# event_whenkeypressed looks_switchbackdropto looks_backdrops control_wait_until operator_equals sensing_timer looks_switchbackdropto looks_backdrops
#
# event_whenkeypressed control_wait_until operator_equals looks_switchbackdropto looks_backdrops control_wait control_stop
#
# event_whenkeypressed control_wait_until operator_equals sensing_timer looks_switchbackdropto looks_backdrops
#
# event_whenkeypressed sensing_resettimer control_wait_until operator_equals sensing_timer looks_switchbackdropto looks_backdrops looks_hide
#
# event_whenflagclicked looks_show data_setvariableto data_hidevariable data_showvariable looks_switchcostumeto looks_costume looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs
#
# event_whenkeypressed looks_switchcostumeto looks_costume data_setvariableto data_showvariable looks_switchbackdropto looks_backdrops
#
# event_whenkeypressed control_wait_until operator_equals sensing_timer looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs
#
# event_whenkeypressed control_wait_until operator_equals looks_switchbackdropto looks_backdrops looks_sayforsecs looks_sayforsecs looks_hide
#
# event_whenkeypressed control_wait_until operator_equals looks_switchbackdropto looks_backdrops looks_switchcostumeto looks_costume looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs
#
# event_whenkeypressed looks_hide
#
# event_whenkeypressed control_wait_until operator_equals sensing_timer looks_hide
#
# event_whenthisspriteclicked looks_hide control_wait motion_gotoxy looks_show control_wait motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby looks_hide motion_gotoxy looks_show control_wait motion_glidesecstoxy
#
# event_whenkeypressed control_wait control_repeat_until operator_equals looks_hide motion_gotoxy looks_show control_wait motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby looks_hide control_wait motion_gotoxy looks_show control_wait motion_glidesecstoxy
#
# event_whenthisspriteclicked looks_hide control_wait motion_gotoxy control_wait looks_show control_wait motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby looks_hide motion_gotoxy looks_show control_wait motion_glidesecstoxy
#
# event_whenkeypressed looks_hide
#
# event_whenkeypressed control_wait_until operator_equals sensing_timer looks_hide
#
# event_whenkeypressed control_wait control_repeat_until operator_equals looks_hide control_wait motion_gotoxy looks_show control_wait motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby looks_hide motion_gotoxy looks_show control_wait motion_glidesecstoxy
#
# event_whenthisspriteclicked looks_hide control_wait motion_gotoxy looks_show control_wait motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby looks_hide motion_gotoxy looks_show control_wait motion_glidesecstoxy
#
# event_whenkeypressed looks_hide
#
# event_whenkeypressed control_wait_until operator_equals sensing_timer looks_hide
#
# event_whenkeypressed control_repeat_until operator_equals looks_hide control_wait motion_gotoxy looks_show control_wait motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby looks_hide motion_gotoxy looks_show control_wait motion_glidesecstoxy
#
# event_whenthisspriteclicked looks_hide control_wait motion_gotoxy looks_show control_wait motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby looks_hide motion_gotoxy looks_show control_wait motion_glidesecstoxy
#
# event_whenkeypressed looks_hide
#
# event_whenkeypressed control_wait_until operator_equals sensing_timer looks_hide
#
# event_whenkeypressed control_wait control_repeat_until operator_equals looks_hide control_wait motion_gotoxy looks_show control_wait motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby looks_hide motion_gotoxy looks_show control_wait motion_glidesecstoxy
#
# event_whenkeypressed looks_hide
#
# event_whenkeypressed control_wait control_repeat_until operator_equals looks_hide motion_gotoxy looks_show control_wait motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby looks_hide motion_gotoxy looks_show control_wait motion_glidesecstoxy
#
# event_whenkeypressed sensing_resettimer
#
# event_whenthisspriteclicked looks_hide control_wait motion_gotoxy looks_show control_wait motion_glidesecstoxy control_if sensing_touchingobject sensing_touchingobjectmenu data_changevariableby looks_hide motion_gotoxy looks_show control_wait motion_glidesecstoxy
#
# event_whenflagclicked control_if sensing_keypressed sensing_keyoptions sensing_resettimer control_wait_until operator_equals sensing_timer looks_hide
#
# event_whenkeypressed control_if operator_equals looks_hide
#
# event_whenflagclicked looks_show
#
# event_whenthisspriteclicked control_repeat_until operator_equals sensing_timer data_showvariable looks_hide looks_seteffectto control_wait looks_show control_wait looks_changeeffectby data_changevariableby
#
# event_whenkeypressed data_setvariableto data_showvariable control_wait sensing_resettimer control_repeat_until operator_equals sensing_timer looks_hide control_wait looks_show control_wait looks_changeeffectby data_changevariableby control_wait looks_hide looks_seteffectto control_wait_until operator_equals looks_hide
#
# event_whenkeypressed data_hidevariable data_setvariableto data_showvariable control_wait sensing_resettimer control_repeat_until operator_equals sensing_timer looks_hide control_wait looks_show control_wait looks_changeeffectby data_changevariableby control_wait looks_hide looks_seteffectto control_wait_until operator_equals looks_hide
#
# event_whenthisspriteclicked control_repeat_until operator_equals sensing_timer looks_hide looks_seteffectto control_wait looks_show control_wait looks_changeeffectby data_changevariableby
#
# ...
#
# event_whenthisspriteclicked
#
# event_whenflagclicked
#
# event_whenthisspriteclicked control_repeat motion_movesteps control_wait data_setvariableto motion_pointtowards motion_pointtowards_menu motion_pointindirection
#
# event_whenflagclicked looks_hide
#
# event_whenflagclicked looks_hide
#
# control_wait looks_show
#
# motion_gotoxy
#
# event_whenbackdropswitchesto looks_show motion_gotoxy control_repeat_until operator_equals motion_xposition motion_movesteps
#
# control_if
#
# sensing_touchingobject sensing_touchingobjectmenu
#
# control_if
#
# control_if
#
# looks_backdropnumbername
#
# control_forever
#
# motion_gotoxy
#
# event_whenthisspriteclicked motion_gotoxy control_forever
#
# motion_movesteps
#
# data_changevariableby
#
# event_whenflagclicked looks_hide
#
# control_wait looks_show
#
# event_whenflagclicked
#
# event_whenbackdropswitchesto looks_show control_forever looks_show motion_pointindirection looks_switchcostumeto looks_costume control_if sensing_touchingobject sensing_touchingobjectmenu motion_pointindirection control_wait looks_hide control_forever looks_cleargraphiceffects
#
# control_if sensing_touchingobject sensing_touchingobjectmenu motion_pointindirection control_wait looks_hide
#
# motion_ifonedgebounce
#
# event_whenflagclicked looks_hide
#
# control_wait looks_show
#
# control_wait looks_show
#
# event_whenflagclicked looks_hide
#
# event_whenflagclicked looks_hide
#
# control_wait looks_show
#
# control_wait looks_show
#
# looks_nextcostume control_if sensing_touchingobject sensing_touchingobjectmenu looks_show
#
# event_whenflagclicked looks_hide
#
# control_wait
#
# event_whenflagclicked looks_hide
#
# event_whenkeypressed looks_nextcostume
#
# control_wait looks_show
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenkeypressed looks_nextcostume
#
# event_whenflagclicked looks_hide
#
# control_wait looks_show
#
# event_whenflagclicked
#
# event_whenflagclicked looks_hide
#
# event_whenbackdropswitchesto motion_ifonedgebounce control_forever looks_show motion_pointindirection looks_switchcostumeto looks_costume control_if sensing_touchingobject sensing_touchingobjectmenu motion_pointindirection control_wait looks_hide control_forever looks_cleargraphiceffects
#
# control_wait looks_show
#
# event_whenflagclicked looks_hide
#
# event_whenflagclicked control_repeat control_wait
#
# event_whenflagclicked control_repeat control_wait sound_play sound_sounds_menu
#
# event_whenbackdropswitchesto motion_ifonedgebounce control_forever looks_show motion_pointindirection looks_switchcostumeto looks_costume control_if sensing_touchingobject sensing_touchingobjectmenu motion_pointindirection control_wait looks_hide control_forever looks_cleargraphiceffects
#
# event_whenflagclicked
#
# event_whenflagclicked looks_hide
#
# event_whenbackdropswitchesto motion_ifonedgebounce control_forever looks_show motion_pointindirection looks_switchcostumeto looks_costume control_if sensing_touchingobject sensing_touchingobjectmenu motion_pointindirection control_wait looks_hide control_forever looks_cleargraphiceffects
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenkeypressed looks_nextcostume
#
# event_whenflagclicked looks_hide control_wait looks_show
#
# event_whenbackdropswitchesto looks_show
#
# event_whenthisspriteclicked looks_switchbackdropto looks_backdrops looks_hide
#
# event_whenflagclicked looks_switchbackdropto looks_backdrops
#
# event_whenbroadcastreceived looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops control_wait looks_switchbackdroptoandwait looks_backdrops
#
# event_whenflagclicked data_setvariableto
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenkeypressed looks_show data_changevariableby
#
# event_whenbroadcastreceived looks_hide data_setvariableto
#
# control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_show looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs control_wait looks_sayforsecs looks_sayforsecs control_wait looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_hide
#
# event_whenkeypressed motion_gotoxy
#
# event_whenkeypressed looks_switchcostumeto looks_costume
#
# event_whenbroadcastreceived looks_show control_wait looks_switchcostumeto looks_costume motion_glidesecstoxy sound_play sound_sounds_menu control_wait event_broadcast data_setvariableto looks_hide control_repeat control_wait motion_gotoxy looks_show motion_glidesecstoxy control_repeat control_wait motion_gotoxy looks_show motion_glidesecstoxy control_repeat control_wait motion_gotoxy looks_show motion_glidesecstoxy
#
# event_whenflagclicked looks_hide motion_gotoxy
#
# event_whenbroadcastreceived motion_gotoxy
#
# event_whenbroadcastreceived data_changevariableby
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenkeypressed looks_show data_changevariableby
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenkeypressed looks_show data_changevariableby
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenkeypressed looks_show data_changevariableby event_broadcast
#
# event_whenflagclicked control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenkeypressed looks_show data_changevariableby
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide data_setvariableto
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenkeypressed looks_show data_changevariableby
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenkeypressed looks_show data_changevariableby event_broadcast
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide data_setvariableto
#
# event_whenflagclicked looks_hide
#
# event_whenbroadcastreceived looks_hide
#
# event_whenkeypressed looks_show data_changevariableby
#
# event_whenflagclicked control_forever control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide data_setvariableto
#
# event_whenflagclicked looks_hide data_setvariableto
#
# event_whenbroadcastreceived looks_hide
#
# event_whenkeypressed looks_show data_changevariableby event_broadcast looks_switchbackdropto looks_backdrops
#
# event_whenbroadcastreceived looks_show
#
# event_whenflagclicked looks_hide
#
# event_whenflagclicked
#
# sound_play sound_sounds_menu
#
# event_whenflagclicked looks_show
#
# event_whenthisspriteclicked event_broadcast
#
# event_whenbroadcastreceived looks_switchbackdropto looks_backdrops
#
# event_whenbroadcastreceived looks_hide
#
# event_whenthisspriteclicked sound_play sound_sounds_menu
#
# event_whenflagclicked looks_switchbackdropto looks_backdrops control_wait looks_switchbackdropto looks_backdrops
#
# event_whenflagclicked looks_hide control_wait looks_show data_setvariableto control_repeat data_changevariableby control_wait looks_switchbackdropto looks_backdrops event_broadcast
#
# event_whenbroadcastreceived looks_hide
#
# event_whenflagclicked data_setvariableto motion_glidesecstoxy looks_switchbackdropto looks_backdrops looks_hide motion_glidesecstoxy control_wait looks_switchbackdropto looks_backdrops looks_show control_wait motion_glidesecstoxy control_repeat motion_glidesecstoxy looks_show motion_glidesecstoxy operator_random operator_random control_wait looks_hide
#
# event_whenthisspriteclicked sound_play sound_sounds_menu data_changevariableby looks_hide
#
# control_repeat sensing_resettimer
#
# event_whenflagclicked data_setvariableto looks_hide control_wait looks_show motion_gotoxy looks_show control_forever motion_movesteps control_wait control_if sensing_touchingobject sensing_touchingobjectmenu looks_hide
#
# event_whenflagclicked looks_hide control_wait motion_gotoxy looks_show control_forever motion_movesteps control_wait control_if sensing_touchingobject sensing_touchingobjectmenu control_wait looks_hide
#
# event_whenflagclicked looks_hide control_wait looks_show control_wait looks_hide
#
# event_whenflagclicked data_setvariableto motion_glidesecstoxy looks_switchbackdropto looks_backdrops looks_hide motion_glidesecstoxy control_wait looks_switchbackdropto looks_backdrops looks_show control_wait motion_glidesecstoxy control_repeat motion_glidesecstoxy looks_show motion_glidesecstoxy operator_random operator_random control_wait looks_hide
#
# event_whenthisspriteclicked sound_play sound_sounds_menu data_changevariableby looks_hide
#
# event_whenflagclicked data_setvariableto motion_glidesecstoxy looks_switchbackdropto looks_backdrops looks_hide motion_glidesecstoxy control_wait looks_switchbackdropto looks_backdrops looks_show control_wait motion_glidesecstoxy control_repeat motion_glidesecstoxy looks_show motion_glidesecstoxy operator_random operator_random control_wait looks_hide
#
# event_whenthisspriteclicked sound_play sound_sounds_menu data_changevariableby looks_hide
#
# event_whenflagclicked data_setvariableto motion_glidesecstoxy looks_switchbackdropto looks_backdrops looks_hide motion_glidesecstoxy control_wait looks_switchbackdropto looks_backdrops looks_show control_wait motion_glidesecstoxy control_repeat motion_glidesecstoxy looks_show motion_glidesecstoxy operator_random operator_random control_wait looks_hide
#
# event_whenthisspriteclicked sound_play sound_sounds_menu data_changevariableby looks_hide
#
# event_whenflagclicked data_setvariableto motion_glidesecstoxy looks_switchbackdropto looks_backdrops looks_hide motion_glidesecstoxy control_wait looks_switchbackdropto looks_backdrops looks_show control_wait motion_glidesecstoxy control_repeat motion_glidesecstoxy looks_show motion_glidesecstoxy operator_random operator_random control_wait looks_hide
#
# event_whenthisspriteclicked sound_play sound_sounds_menu data_changevariableby looks_hide
#
# event_whenflagclicked data_setvariableto motion_glidesecstoxy looks_switchbackdropto looks_backdrops looks_hide motion_glidesecstoxy control_wait looks_switchbackdropto looks_backdrops looks_show control_wait motion_glidesecstoxy control_repeat motion_glidesecstoxy looks_show motion_glidesecstoxy operator_random operator_random control_wait looks_hide
#
# event_whenthisspriteclicked sound_play sound_sounds_menu data_changevariableby looks_hide
#
# event_whenflagclicked data_setvariableto motion_glidesecstoxy looks_switchbackdropto looks_backdrops looks_hide motion_glidesecstoxy control_wait looks_switchbackdropto looks_backdrops looks_show control_wait motion_glidesecstoxy control_repeat motion_glidesecstoxy looks_show motion_glidesecstoxy operator_random operator_random control_wait looks_hide
#
# event_whenthisspriteclicked sound_play sound_sounds_menu data_changevariableby looks_hide
#
# event_whenflagclicked data_setvariableto motion_glidesecstoxy looks_switchbackdropto looks_backdrops looks_hide motion_glidesecstoxy control_wait looks_switchbackdropto looks_backdrops looks_show control_wait motion_glidesecstoxy control_repeat motion_glidesecstoxy looks_show motion_glidesecstoxy operator_random operator_random control_wait looks_hide
#
# event_whenthisspriteclicked sound_play sound_sounds_menu data_changevariableby looks_hide
#
# data_setvariableto
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_forever control_if operator_gt looks_switchcostumeto looks_costume control_if operator_gt looks_switchcostumeto looks_costume control_if operator_gt looks_switchcostumeto looks_costume control_if operator_gt looks_switchcostumeto looks_costume control_if operator_gt looks_switchcostumeto looks_costume
#
# operator_equals
#
# operator_equals
#
# event_whenflagclicked
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_forever control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_and sensing_touchingobject sensing_touchingobjectmenu sensing_keypressed sensing_keyoptions looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_equals looks_hide
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_forever control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_and sensing_touchingobject sensing_touchingobjectmenu sensing_keypressed sensing_keyoptions looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_equals looks_hide
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_forever control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_and sensing_touchingobject sensing_touchingobjectmenu sensing_keypressed sensing_keyoptions looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_equals looks_hide
#
# event_whenflagclicked control_forever control_if operator_and sensing_touchingobject sensing_touchingobjectmenu sensing_keypressed sensing_keyoptions looks_switchcostumeto looks_costume
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_forever control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_equals looks_hide
#
# event_whenflagclicked control_forever control_if operator_and sensing_touchingobject sensing_touchingobjectmenu sensing_keypressed sensing_keyoptions looks_switchcostumeto looks_costume
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_forever control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_equals looks_hide
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_wait looks_switchcostumeto looks_costume
#
# event_whenflagclicked looks_show looks_switchcostumeto looks_costume control_wait control_forever control_wait operator_random looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_and sensing_touchingobject sensing_touchingobjectmenu sensing_keypressed sensing_keyoptions looks_switchcostumeto looks_costume
#
# event_whenflagclicked control_forever control_if operator_equals looks_hide
#
# event_whenflagclicked data_showvariable looks_switchbackdropto looks_backdrops looks_sayforsecs control_wait looks_sayforsecs control_wait looks_sayforsecs sensing_resettimer
#
# event_whenflagclicked data_setvariableto control_wait control_forever control_wait data_changevariableby
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenflagclicked data_setvariableto control_wait control_forever control_if sensing_keypressed sensing_keyoptions control_wait data_changevariableby
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenkeypressed motion_pointindirection motion_movesteps
#
# event_whenflagclicked control_forever control_if operator_equals data_hidevariable looks_switchbackdropto looks_backdrops looks_sayforsecs looks_sayforsecs looks_sayforsecs looks_sayforsecs control_stop

# %% [markdown]
# ## CREATION OF DATASET

# %%
class SkipGramData(Dataset):
    def __init__(self, corpus, window_sz= 2):
        super().__init__
        self.corpus = corpus
        self.window = window_sz
        self.vocab = list(set(token.lower() for sentence in self.corpus for token in sentence.split())) # set elimina dups y no mantiene el orden
        self.word2idx = {word: idx for idx, word in enumerate(self.vocab)}
        self.idx2word = {idx: word for word, idx in self.word2idx.items()}
        self.data = self.gen_dataset()

    def gen_dataset(self):
        # Metod for enventanado
        data = []
        for sentence in self.corpus:
            text = sentence.lower().split()
            #print(text)
            for center_idx, center_word in enumerate(text):
                for offset in range(-self.window, self.window +1):
                    context_idx = center_idx + offset
                    if context_idx < 0 or context_idx >= len(text) or context_idx == center_idx: continue
                    context_word = text[context_idx]
                    data.append((self.word2idx[center_word], self.word2idx[context_word]))
        return data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

# %% [markdown]
# ## CREATION OF MODEL AND TRAINING FUNCTION

# %%
class SkipGram(nn.Module):
    def __init__(self, vocab_sz, embed_sz):
        super().__init__()
        self.embed_layer = nn.Linear(vocab_sz, embed_sz, bias = False)
        self.output_layer = nn.Linear(embed_sz, vocab_sz)

    def forward(self, x):
        return self.output_layer(self.embed_layer(x))

# %%
def train_skipgram(model, loss_function, optimizer, data_loader, epochs=100):
    model.train() 
    for epoch in range(epochs):
        total_loss = 0
        for center, context in data_loader:
            center, context = center.to(device), context.to(device)
            
            center_vector = torch.zeros(len(data_loader.dataset.vocab), device=device) 
            center_vector[center] = 1.0
            center_vector = center_vector.unsqueeze(0)  

            scores = model(center_vector)
            
            labels = torch.tensor([context], dtype=torch.long, device=device)
            loss = loss_function(scores, labels)
            
            # Backward pass y optimización
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            torch.cuda.synchronize() 
            
            # Acumulando la pérdida
            total_loss += loss.item()
        
        # Imprimir la pérdida media por epoch
        print(f'Epoch: {epoch+1}, Loss: {total_loss/len(data_loader)}')

# %% [markdown]
# ## TRAIN

# %%
learning_rate = 0.0001

dataset = SkipGramData(scripts)
print(type(dataset.data))
data_loader = DataLoader(dataset, batch_size=1, shuffle=True)
model = SkipGram(len(dataset.vocab), embed_sz=300).to(device)
optimizer = optim.Adam(model.parameters(), lr= learning_rate)
loss_function = nn.CrossEntropyLoss()

train_skipgram(model, loss_function, optimizer, data_loader, epochs=100)
#for center_idx, context_idx in dataset.data:
    #print(dataset.idx2word[center_idx],dataset.idx2word[context_idx])
# Out:
# <class 'list'>
# Epoch: 1, Loss: 3.1989630293874405
# Epoch: 2, Loss: 2.956430338701384
# Epoch: 3, Loss: 2.9293941429240737
# Epoch: 4, Loss: 2.9167108414760277
# Epoch: 5, Loss: 2.910382150554102
# Epoch: 6, Loss: 2.9067773499660627
# Epoch: 7, Loss: 2.904870480058773
# Epoch: 8, Loss: 2.903165921894825
# Epoch: 9, Loss: 2.901605930177083
# Epoch: 10, Loss: 2.8999032877804125
# Epoch: 11, Loss: 2.899594333965003
# Epoch: 12, Loss: 2.8996002313957563
# Epoch: 13, Loss: 2.898803346888002
# Epoch: 14, Loss: 2.899196516941668
# Epoch: 15, Loss: 2.898828038059962
# Epoch: 16, Loss: 2.8989487575680624
# Epoch: 17, Loss: 2.898898392590821
# Epoch: 18, Loss: 2.89891077324093
# Epoch: 19, Loss: 2.8991263952547492
# Epoch: 20, Loss: 2.8986633815800884
# Epoch: 21, Loss: 2.8998955512487927
# Epoch: 22, Loss: 2.89988085955767
# Epoch: 23, Loss: 2.9005333647565736
# Epoch: 24, Loss: 2.9008643587754817
# Epoch: 25, Loss: 2.9003541448008163
# Epoch: 26, Loss: 2.9011107592945127
# Epoch: 27, Loss: 2.901400648135669
# Epoch: 28, Loss: 2.9011192600408657
# Epoch: 29, Loss: 2.901156857917332
# Epoch: 30, Loss: 2.900160685485089
# Epoch: 31, Loss: 2.901196289812457
# Epoch: 32, Loss: 2.903041991879467
# Epoch: 33, Loss: 2.9024776751457213
# Epoch: 34, Loss: 2.9024822397996317
# Epoch: 35, Loss: 2.9023956271351574
# Epoch: 36, Loss: 2.903739649075567
# Epoch: 37, Loss: 2.903874158090995
# Epoch: 38, Loss: 2.9049712782195556
# Epoch: 39, Loss: 2.9041527472421556
# Epoch: 40, Loss: 2.904647181908107
# Epoch: 41, Loss: 2.904884860229843
# Epoch: 42, Loss: 2.90419185040062
# Epoch: 43, Loss: 2.9050430350878513
# Epoch: 44, Loss: 2.9069345227589474
# Epoch: 45, Loss: 2.905102187002166
# Epoch: 46, Loss: 2.906617115952705
# Epoch: 47, Loss: 2.9080559097853476
# Epoch: 48, Loss: 2.9073756145267105
# Epoch: 49, Loss: 2.9071308461184078
# Epoch: 50, Loss: 2.908628422837084
# Epoch: 51, Loss: 2.90820398826333
# Epoch: 52, Loss: 2.9088589356251293
# Epoch: 53, Loss: 2.9089970682426958
# Epoch: 54, Loss: 2.909813639194525
# Epoch: 55, Loss: 2.9089953985145094
# Epoch: 56, Loss: 2.911082332045933
# Epoch: 57, Loss: 2.909705090340307
# Epoch: 58, Loss: 2.9107018418916453
# Epoch: 59, Loss: 2.911147331513892
# Epoch: 60, Loss: 2.9108993042510254
# Epoch: 61, Loss: 2.9119492507444424
# Epoch: 62, Loss: 2.9128950002603933
# Epoch: 63, Loss: 2.9115051458476096
# Epoch: 64, Loss: 2.913740887139717
# Epoch: 65, Loss: 2.913991868693167
# Epoch: 66, Loss: 2.91186062968511
# Epoch: 67, Loss: 2.913830301369289
# Epoch: 68, Loss: 2.9143263888874262
# Epoch: 69, Loss: 2.9132955322933234
# Epoch: 70, Loss: 2.9165766727972393
# Epoch: 71, Loss: 2.9159987448143774
# Epoch: 72, Loss: 2.9160559075307058
# Epoch: 73, Loss: 2.914917859736305
# Epoch: 74, Loss: 2.9181177340379754
# Epoch: 75, Loss: 2.917882217331594
# Epoch: 76, Loss: 2.916858932526865
# Epoch: 77, Loss: 2.917310240420989
# Epoch: 78, Loss: 2.918980432732726
# Epoch: 79, Loss: 2.9185742964722174
# Epoch: 80, Loss: 2.9200649860021484
# Epoch: 81, Loss: 2.9202419297551443
# Epoch: 82, Loss: 2.919937762289119
# Epoch: 83, Loss: 2.9203515761221683
# Epoch: 84, Loss: 2.921550604989209
# Epoch: 85, Loss: 2.9203039292310753
# Epoch: 86, Loss: 2.9222377932736068
# Epoch: 87, Loss: 2.923254877671776
# Epoch: 88, Loss: 2.9225544371908683
# Epoch: 89, Loss: 2.921633171268079
# Epoch: 90, Loss: 2.9228238326790614
# Epoch: 91, Loss: 2.9243831281334063
# Epoch: 92, Loss: 2.9240861429689122
# Epoch: 93, Loss: 2.9247089302315663
# Epoch: 94, Loss: 2.92470113668791
# Epoch: 95, Loss: 2.925172559640096
# Epoch: 96, Loss: 2.9266906975322224
# Epoch: 97, Loss: 2.92632163159766
# Epoch: 98, Loss: 2.927941881075721
# Epoch: 99, Loss: 2.9266875840892963
# Epoch: 100, Loss: 2.928519102880288

# %% [markdown]
# ## PLOTING RESULTS

# %%
def plot_embeddings(embedings, word2idx):
    num_samples = len(word2idx)
    tsne = TSNE(n_components=2, random_state=0)
    vectors = tsne.fit_transform(embeddings)
    plt.figure(figsize=(30,20))
    for word, idx in word2idx.items():
        plt.scatter(vectors[idx, 0], vectors[idx, 1])
        plt.annotate(word, xy=(vectors[idx, 0], vectors[idx, 1]), xytext=(5,2), 
                    textcoords='offset points', ha='right', va='bottom')
    plt.title('Word Embeddings Visualized using t-SNE')
    plt.xlabel('t-SNE Dimension 1')
    plt.ylabel(True)
    plt.show()
    plt.savefig('embedding_action_clicker.png', format='png')

# %%
embeddings = model.embed_layer.weight.detach().cpu().numpy()
plot_embeddings(embeddings, dataset.word2idx)

# %% [markdown]
# ## MODEL SAVING

# %%
# Save trained model
model_path = "embedding_action_clicker.pth"
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict()
}, model_path)

# %%
print("Dispositivo del modelo:", next(model.parameters()).device)
# Out:
# Dispositivo del modelo: cuda:0

# %% [markdown]
# ## Apply K-Means

# %%
# Configurar el número de clusters
n_clusters = 10

# Aplicar K-means
kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(embeddings)
labels = kmeans.labels_
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 5
#       2 n_clusters = 10
#       4 # Aplicar K-means
# ----> 5 kmeans = KMeans(n_clusters=n_clusters, random_state=0).fit(embeddings)
#       6 labels = kmeans.labels_
#
# NameError: name 'KMeans' is not defined
