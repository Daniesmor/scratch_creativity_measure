# %% [markdown]
# # EXTRACT SHOOTER PROJECTS

# %%
import pandas as pd
import os
import shutil
from zipfile import ZipFile, BadZipFile
import json
import numpy as np
from torch.cuda.amp import GradScaler, autocast


import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

print(np.__version__)
# Out:
# 1.26.4

# %%
def check_gpu():
    if torch.cuda.is_available():
        print("CUDA está disponible.")
        print(f"Hay {torch.cuda.device_count()} GPU(s) disponible(s).")
        for i in range(torch.cuda.device_count()):
            print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
    else:
        print("CUDA no está disponible. No hay GPU accesible.")

check_gpu()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# CUDA está disponible.
# Hay 1 GPU(s) disponible(s).
# GPU 0: NVIDIA GeForce RTX 2060

# %%
metrics = pd.read_csv('metrics_attr.csv')

# Filter by Action Genre
metrics_action_pong = metrics[(metrics['Main Genre'] == 'Action') & (metrics['Second Genre']== 'Pong')]
metrics_action_clicker = metrics[(metrics['Main Genre'] == 'Action') & (metrics['Second Genre']== 'Clicker')]

# Check the filenames for collect
filenames_action_pong = list(metrics_action_pong['Name'])
filenames_action_clicker = list(metrics_action_pong['Name'])
# Create txt for made the shell script
#with open('filenames_action_pong.txt', 'w') as names_pong:
  #   for name in filenames_action_pong:
     #   names_pong.write(name + '\n')


#for project in filenames_action_clicker:
 #   sb3_path = f'./projects_sb3/{project}'
  #  if os.path.isfile(sb3_path):
   #     shutil.copy(sb3_path, './sb3_action_clicker')
    #    print(f'The project {project} has been success copy')
    #else:
     #   print(f'The project {project} doesnt exists')

# %%
def load_json_project(path_projectsb3):
    try:
        zip_file = ZipFile(path_projectsb3, "r")
        json_project = json.loads(zip_file.open("project.json").read())
        return json_project
    except BadZipFile:
        print('Bad zipfile')

def process(json_project):
    dict_total_blocks = {}
    list_total_blocks = []

    for key, list_info in json_project.items():
        if key == "targets":
            for dict_target in list_info:
                target_name = dict_target.get('name')
                if target_name:
                    dict_total_blocks[target_name] = []
                
                blocks = dict_target.get('blocks')
                if blocks:
                    for block_id, block_info in blocks.items():
                        if isinstance(block_info, dict):
                            opcode = block_info.get('opcode')
                            if opcode:
                                dict_total_blocks[target_name].append(opcode)
                            list_total_blocks.append(block_info)
                            #dict_total_blocks[block_id] = block_info
    return dict_total_blocks

dict_total_blocks = {}
scripts = []
list_total_blocks = []
print(len(filenames_action_pong))
for project in filenames_action_pong:
    sb3_path = os.path.join('.','sb3_action_pong',project)
    if os.path.isfile(sb3_path):
        print(project)
        json_project = load_json_project(sb3_path)
        dict_total_blocks = process(json_project)

        for sprite, blocks in dict_total_blocks.items():
            if blocks != []:
                scripts.append(" ".join(blocks))

print(scripts)
# Out:
# 69
# Albedo Barrier.sb3
# Albedo Pong.sb3
# Albedo Project.sb3
# Alex and Hannah's project.sb3
# Atmosphere Pong.sb3
# Brick Breaker remix.sb3
# Bryan and Mark's Game Project.sb3
# CAUSATION EVASION.sb3
# CO2 Drop.sb3
# CO2 Stopper Copter.sb3
# CO2 Stopper.sb3
# Carbon Game.sb3
# Climate Change Catch Game.sb3
# Climate Change Game Hannah and Andrew.sb3
# Climate Change Pong Finished Version.sb3
# Climate Control_(2).sb3
# Climate Pong.sb3
# Climate change game-jassec.sb3
# Co2 Catch.sb3
# Cole and Ryan.sb3
# Cow catch game.sb3
# Deforestation Hailey and Remi's Game.sb3
# Dont Go With The Flow.sb3
# ENOZO STOPPER.sb3
# Earth Vs Climate change Dodge ball game.sb3
# Ellie and Talia Untitled-5.sb3
# Falling Fruit Fiesta.sb3
# Harrison And Constantinos.sb3
# Heat absorber.sb3
# Ice Blocker Climate Change Game.sb3
# Ice Pong.sb3
# Island Fish Rescue.sb3
# Leyla and Erin-3 remix remix.sb3
# New Science Scratch.sb3
# PONG CLIMATE CHANGE.sb3
# Patrick and Sawyer Climate Game.sb3
# Polar Saving.sb3
# Preventing CO2 from coming into the Earth.sb3
# Rambunctious Recycling.sb3
# Reducing Ocean Acidification.sb3
# Sammie and Alex Carbon Cycle Project.sb3
# Save The Atmosphere.sb3
# Save The World.sb3
# Save the Climate.sb3
# Saving the Polar Bears.sb3
# Shayan and Jeff.sb3
# Sinking Penguin.sb3
# Soccer Pong.sb3
# Space Game 1: Climate Change.sb3
# Sydney Forristall and Samuel Gordon.sb3
# THE GLOBAL WARMING game!.sb3
# Take Action! - heymynamestrey.sb3
# The Green House Game.sb3
# The Greenhouse Effect.sb3
# TreezRKool.sb3
# Untitled-3_(4).sb3
# Yinyao Duan.sb3
# Zach and Nico.sb3
# Zhimin and Isabella.sb3
# beat the heat.sb3
# catch the CO2 by Olivia and Polina.sb3
# climate change pong.sb3
# ice saver.sb3
# ice tray albedo edition.sb3
# jabby.sb3
# kill the CO2.sb3
# ['event_whenflagclicked control_forever control_if_else operator_equals looks_switchbackdropto looks_backdrops control_if_else operator_equals looks_switchbackdropto looks_backdrops control_if_else operator_equals looks_switchbackdropto looks_backdrops control_if_else operator_equals looks_switchbackdropto looks_backdrops control_if_else operator_equals looks_switchbackdropto looks_backdrops control_if_else operator_equals looks_switchbackdropto looks_backdrops control_if_else operator_equals looks_switchbackdropto looks_backdrops control_if operator_equals looks_switchbackdropto looks_backdrops', 'event_whenflagclicked data_setvariableto data_setvariableto looks_show motion_gotoxy data_setvariableto control_forever control_if operator_or operator_gt operator_equals event_broadcastandwait event_whenbroadcastreceived data_setvariableto data_changevariableby event_broadcast control_create_clone_of control_create_clone_of_menu event_whenbroadcastreceived looks_hide', 'event_whenflagclicked control_forever motion_pointindirection control_if sensing_keypressed sensing_keyoptions control_if operator_gt motion_xposition control_if_else operator_gt motion_movesteps operator_multiply motion_movesteps event_whenflagclicked control_forever motion_pointindirection control_if sensing_keypressed sensing_keyoptions control_if operator_lt motion_xposition control_if_else operator_gt motion_movesteps operator_multiply motion_movesteps event_whenbroadcastreceived looks_hide event_whenbroadcastreceived data_changevariableby event_whenbroadcastreceived data_changevariableby event_whenflagclicked data_setvariableto data_setvariableto data_setvariableto control_forever control_if_else operator_equals looks_switchcostumeto looks_costume control_if_else operator_equals looks_switchcostumeto looks_costume control_if_else operator_equals looks_switchcostumeto looks_costume control_if_else operator_equals looks_switchcostumeto looks_costume control_if operator_equals looks_switchcostumeto looks_costume event_whenflagclicked looks_switchcostumeto looks_costume looks_show motion_gotoxy', 'control_start_as_clone motion_gotoxy operator_random looks_show control_forever control_if_else operator_equals control_delete_this_clone control_if_else operator_not operator_or operator_or sensing_touchingobject sensing_touchingobjectmenu sensing_touchingobject sensing_touchingobjectmenu operator_equals motion_yposition motion_pointindirection motion_movesteps operator_multiply control_if_else sensing_touchingobject sensing_touchingobjectmenu event_broadcast control_delete_this_clone control_if sensing_touchingobject sensing_touchingobjectmenu control_repeat_until operator_equals motion_yposition motion_glidesecstoxy operator_random control_delete_this_clone event_whenflagclicked data_setvariableto looks_hide control_forever control_wait operator_divide control_create_clone_of control_create_clone_of_menu event_whenflagclicked control_forever control_wait data_setvariableto data_setvariableto operator_add event_broadcast event_whenbroadcastreceived data_setvariableto control_forever control_wait', 'event_whenbroadcastreceived looks_hide event_whenflagclicked looks_show', 'event_whenbroadcastreceived looks_hide event_whenflagclicked looks_show', 'event_whenbroadcastreceived looks_hide event_whenflagclicked looks_show', 'event_whenbroadcastreceived looks_hide event_whenflagclicked looks_gotofrontback looks_show', 'event_whenbroadcastreceived looks_hide event_whenflagclicked looks_show event_whenflagclicked control_forever control_if_else operator_equals looks_sayforsecs control_wait control_if_else operator_equals looks_sayforsecs control_wait control_if_else operator_equals looks_sayforsecs control_wait control_if operator_equals looks_sayforsecs control_wait', 'event_whenflagclicked looks_gotofrontback looks_hide data_showvariable data_showvariable event_whenbroadcastreceived motion_gotoxy looks_show data_hidevariable data_hidevariable', 'control_start_as_clone looks_s ...

# %%
class SkipGramData(Dataset):
    def __init__(self, corpus, window_sz= 2):
        super().__init__
        self.corpus = corpus
        self.window = window_sz
        self.vocab = list(set(token.lower() for sentence in self.corpus for token in sentence.split())) # set elimina dups y no mantiene el orden
        self.word2idx = {word: idx for idx, word in enumerate(self.vocab)}
        self.idx2word = {idx: word for word, idx in self.word2idx.items()}
        self.data = self.gen_dataset()

    def gen_dataset(self):
        # Metod for enventanado
        data = []
        for sentence in self.corpus:
            text = sentence.lower().split()
            #print(text)
            for center_idx, center_word in enumerate(text):
                for offset in range(-self.window, self.window +1):
                    context_idx = center_idx + offset
                    if context_idx < 0 or context_idx >= len(text) or context_idx == center_idx: continue
                    context_word = text[context_idx]
                    data.append((self.word2idx[center_word], self.word2idx[context_word]))
        return data

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        return self.data[idx]

# %%
class SkipGram(nn.Module):
    def __init__(self, vocab_sz, embed_sz):
        super().__init__()
        self.embed_layer = nn.Linear(vocab_sz, embed_sz, bias = False)
        self.output_layer = nn.Linear(embed_sz, vocab_sz)

    def forward(self, x):
        return self.output_layer(self.embed_layer(x))

# %%
def train_skipgram(model, loss_function, optimizer, data_loader, epochs=100):
    model.train() 
    for epoch in range(epochs):
        total_loss = 0
        for center, context in data_loader:
            center, context = center.to(device), context.to(device)
            
            center_vector = torch.zeros(len(data_loader.dataset.vocab), device=device) 
            center_vector[center] = 1.0
            center_vector = center_vector.unsqueeze(0)  

            scores = model(center_vector)
            
            labels = torch.tensor([context], dtype=torch.long, device=device)
            loss = loss_function(scores, labels)
            
            # Backward pass y optimización
            optimizer.zero_grad()
            loss.backward()
            optimizer.step()

            torch.cuda.synchronize() 
            
            # Acumulando la pérdida
            total_loss += loss.item()
        
        # Imprimir la pérdida media por epoch
        print(f'Epoch: {epoch+1}, Loss: {total_loss/len(data_loader)}')

# %%
learning_rate = 0.0001

dataset = SkipGramData(scripts)
print(type(dataset.data))
data_loader = DataLoader(dataset, batch_size=1, shuffle=True)
model = SkipGram(len(dataset.vocab), embed_sz=300).to(device)
optimizer = optim.Adam(model.parameters(), lr= learning_rate)
loss_function = nn.CrossEntropyLoss()

train_skipgram(model, loss_function, optimizer, data_loader, epochs=200)
#for center_idx, context_idx in dataset.data:
    #print(dataset.idx2word[center_idx],dataset.idx2word[context_idx])
# Out:
# <class 'list'>
# Epoch: 147, Loss: 3.1084336286104195
# Epoch: 148, Loss: 3.107277130676849
# Epoch: 149, Loss: 3.1093311248053292
# Epoch: 150, Loss: 3.1097464937857504
# Epoch: 151, Loss: 3.1102951007070856
# Epoch: 152, Loss: 3.112383647188052
# Epoch: 153, Loss: 3.109657061010993
# Epoch: 154, Loss: 3.1104279460578304
# Epoch: 155, Loss: 3.1096888994030722
# Epoch: 156, Loss: 3.111157829136823
# Epoch: 157, Loss: 3.1127266297404432
# Epoch: 158, Loss: 3.11392375001003
# Epoch: 159, Loss: 3.1129310533927064
# Epoch: 160, Loss: 3.1135314775448073
# Epoch: 161, Loss: 3.112846169214196
# Epoch: 162, Loss: 3.113611153890583
# Epoch: 163, Loss: 3.1125495216068857
# Epoch: 164, Loss: 3.112755592691481
# Epoch: 165, Loss: 3.1134638001219668
# Epoch: 166, Loss: 3.113611108608578
# Epoch: 167, Loss: 3.1161182595317474
# Epoch: 168, Loss: 3.1161874904771554
# Epoch: 169, Loss: 3.116338123190991
# Epoch: 170, Loss: 3.116770840864114
# Epoch: 171, Loss: 3.115156635574566
# Epoch: 172, Loss: 3.116670239003654
# Epoch: 173, Loss: 3.116009353865882
# Epoch: 174, Loss: 3.1168428349726747
# Epoch: 175, Loss: 3.1177616642559207
# Epoch: 176, Loss: 3.1181486340145894
# Epoch: 177, Loss: 3.1186310150796146
# Epoch: 178, Loss: 3.1175907628594
# Epoch: 179, Loss: 3.1200511998303297
# Epoch: 180, Loss: 3.118385684024306
# Epoch: 181, Loss: 3.118603339864655
# Epoch: 182, Loss: 3.120980976611866
# Epoch: 183, Loss: 3.1202100656037763
# Epoch: 184, Loss: 3.119993519516486
# Epoch: 185, Loss: 3.1191769746130773
# Epoch: 186, Loss: 3.121014487475202
# Epoch: 187, Loss: 3.120539687182505
# Epoch: 188, Loss: 3.1222827968865485
# Epoch: 189, Loss: 3.120534501160932
# Epoch: 190, Loss: 3.121864763273842
# Epoch: 191, Loss: 3.1224527570723457
# Epoch: 192, Loss: 3.1230984730176643
# Epoch: 193, Loss: 3.1249273578914276
# Epoch: 194, Loss: 3.1237795407131475
# Epoch: 195, Loss: 3.124259375858723
# Epoch: 196, Loss: 3.125038883006309
# Epoch: 197, Loss: 3.1238520259322646
# Epoch: 198, Loss: 3.1235261253756277
# Epoch: 199, Loss: 3.1243340722434985
# Epoch: 200, Loss: 3.124051550308858

# %%
def plot_embeddings(embedings, word2idx):
    num_samples = len(word2idx)
    tsne = TSNE(n_components=2, random_state=0)
    vectors = tsne.fit_transform(embeddings)
    plt.figure(figsize=(30,20))
    for word, idx in word2idx.items():
        plt.scatter(vectors[idx, 0], vectors[idx, 1])
        plt.annotate(word, xy=(vectors[idx, 0], vectors[idx, 1]), xytext=(5,2), 
                    textcoords='offset points', ha='right', va='bottom')
    plt.title('Word Embeddings Visualized using t-SNE')
    plt.xlabel('t-SNE Dimension 1')
    plt.ylabel(True)
    plt.show()
    plt.savefig('embedding_action_pong.png', format='png')

# %%
embeddings = model.embed_layer.weight.detach().cpu().numpy()
plot_embeddings(embeddings, dataset.word2idx)

# %%
# Save trained model
model_path = "embedding_action_pong.pth"
torch.save({
    'model_state_dict': model.state_dict(),
    'optimizer_state_dict': optimizer.state_dict()
}, model_path)

# %%
print("Dispositivo del modelo:", next(model.parameters()).device)
# Out:
# Dispositivo del modelo: cuda:0
