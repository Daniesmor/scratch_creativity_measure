# %% [markdown]
# #

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from collections import Counter
import math
import numpy as np
import re
import os
import pandas as pd
import os
from zipfile import ZipFile, BadZipFile
import json
from sklearn.metrics.pairwise import cosine_similarity, euclidean_distances


os.environ['CUDA_LAUNCH_BLOCKING'] = '1'

torch.manual_seed(23)

# %%
def check_gpu():
    if torch.cuda.is_available():
        print("CUDA está disponible.")
        print(f"Hay {torch.cuda.device_count()} GPU(s) disponible(s).")
        for i in range(torch.cuda.device_count()):
            print(f"GPU {i}: {torch.cuda.get_device_name(i)}")
    else:
        print("CUDA no está disponible. No hay GPU accesible.")

check_gpu()
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
# Out:
# CUDA está disponible.
# Hay 1 GPU(s) disponible(s).
# GPU 0: NVIDIA GeForce RTX 2060

# %% [markdown]
# ## TRANSFORMER ARCHITECTURE

# %%
MAX_SEQ_LEN = 128 # max num of words per phrase for translate

# %%
class PositionalEmbedding(nn.Module):
    def __init__(self, d_model, max_seq_len = MAX_SEQ_LEN):
        super().__init__()
        self.pos_embed_matrix = torch.zeros(max_seq_len, d_model, device=device)
        token_pos = torch.arange(0, max_seq_len, dtype = torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() 
                             * (-math.log(10000.0)/d_model))
        self.pos_embed_matrix[:, 0::2] = torch.sin(token_pos * div_term)
        self.pos_embed_matrix[:, 1::2] = torch.cos(token_pos * div_term)
        self.pos_embed_matrix = self.pos_embed_matrix.unsqueeze(0).transpose(0,1)
        
    def forward(self, x):
#         print(self.pos_embed_matrix.shape)
#         print(x.shape)
        return x + self.pos_embed_matrix[:x.size(0), :]

class MultiHeadAttention(nn.Module):
    def __init__(self, d_model = 512, num_heads = 8):
        super().__init__()
        assert d_model % num_heads == 0, 'Embedding size not compatible with num heads'
        
        self.d_v = d_model // num_heads
        self.d_k = self.d_v
        self.num_heads = num_heads
        
        self.W_q = nn.Linear(d_model, d_model)
        self.W_k = nn.Linear(d_model, d_model)
        self.W_v = nn.Linear(d_model, d_model)
        self.W_o = nn.Linear(d_model, d_model)
        
    def forward(self, Q, K, V, mask = None):
        batch_size = Q.size(0)
        '''
        Q, K, V -> [batch_size, seq_len, num_heads*d_k]
        after transpose Q, K, V -> [batch_size, num_heads, seq_len, d_k]
        '''
        Q = self.W_q(Q).view(batch_size, -1, self.num_heads, self.d_k).transpose(1, 2 )
        K = self.W_k(K).view(batch_size, -1, self.num_heads, self.d_k).transpose(1, 2 )
        V = self.W_v(V).view(batch_size, -1, self.num_heads, self.d_k).transpose(1, 2 )
        
        weighted_values, attention = self.scale_dot_product(Q, K, V, mask)
        weighted_values = weighted_values.transpose(1, 2).contiguous().view(batch_size, -1, self.num_heads*self.d_k)
        weighted_values = self.W_o(weighted_values)
        
        return weighted_values, attention
        
        
    def scale_dot_product(self, Q, K, V, mask = None):
        scores = torch.matmul(Q, K.transpose(-2, -1)) / math.sqrt(self.d_k)
        if mask is not None:
            scores = scores.masked_fill(mask == 0, -1e9)
        attention = F.softmax(scores, dim = -1)
        weighted_values = torch.matmul(attention, V)
        
        return weighted_values, attention
        

class PositionFeedForward(nn.Module):
    def __init__(self, d_model, d_ff):
        super().__init__()
        self.linear1 = nn.Linear(d_model, d_ff)
        self.linear2 = nn.Linear(d_ff, d_model)
        
    def forward(self, x):
        return self.linear2(F.relu(self.linear1(x)))
    
class EncoderSubLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout = 0.1):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.ffn = PositionFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.droupout1 = nn.Dropout(dropout)
        self.droupout2 = nn.Dropout(dropout)
    
    def forward(self, x, mask = None):
        attention_score, _ = self.self_attn(x, x, x, mask)
        x = x + self.droupout1(attention_score)
        x = self.norm1(x)
        x = x + self.droupout2(self.ffn(x))
        return self.norm2(x)

class Encoder(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, num_layers, dropout=0.1):
        super().__init__()
        self.layers = nn.ModuleList([EncoderSubLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.norm = nn.LayerNorm(d_model)
    def forward(self, x, mask=None):
        for layer in self.layers:
            x = layer(x, mask)
        return self.norm(x)

class DecoderSubLayer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, dropout=0.1):
        super().__init__()
        self.self_attn = MultiHeadAttention(d_model, num_heads)
        self.cross_attn = MultiHeadAttention(d_model, num_heads)
        self.feed_forward = PositionFeedForward(d_model, d_ff)
        self.norm1 = nn.LayerNorm(d_model)
        self.norm2 = nn.LayerNorm(d_model)
        self.norm3 = nn.LayerNorm(d_model)
        self.dropout1 = nn.Dropout(dropout)
        self.dropout2 = nn.Dropout(dropout)
        self.dropout3 = nn.Dropout(dropout)
        
    def forward(self, x, encoder_output, target_mask=None, encoder_mask=None):
        attention_score, _ = self.self_attn(x, x, x, target_mask)
        x = x + self.dropout1(attention_score)
        x = self.norm1(x)
        
        encoder_attn, _ = self.cross_attn(x, encoder_output, encoder_output, encoder_mask)
        x = x + self.dropout2(encoder_attn)
        x = self.norm2(x)
        
        ff_output = self.feed_forward(x)
        x = x + self.dropout3(ff_output)
        return self.norm3(x)
        
class Decoder(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, num_layers, dropout=0.1):
        super().__init__()
        self.layers = nn.ModuleList([DecoderSubLayer(d_model, num_heads, d_ff, dropout) for _ in range(num_layers)])
        self.norm = nn.LayerNorm(d_model)
        
    def forward(self, x, encoder_output, target_mask, encoder_mask):
        for layer in self.layers:
            x = layer(x, encoder_output, target_mask, encoder_mask)
        return self.norm(x)

# %%
class Transformer(nn.Module):
    def __init__(self, d_model, num_heads, d_ff, num_layers,
                 input_vocab_size, max_len=MAX_SEQ_LEN, dropout=0.1):
        super().__init__()
        self.encoder_embedding = nn.Embedding(input_vocab_size, d_model)
        self.pos_embedding = PositionalEmbedding(d_model, max_len)
        self.encoder = Encoder(d_model, num_heads, d_ff, num_layers, dropout)

        # Embeddings
        self._cached_source_embeddings = None
        
    def forward(self, source):
        # Encoder mask
        source_mask = self.mask(source)
        # Embedding and positional Encoding
        source = self.encoder_embedding(source) * math.sqrt(self.encoder_embedding.embedding_dim)
        self._cached_source_embeddings = source
        source = self.pos_embedding(source)
        # Encoder
        encoder_output = self.encoder(source, source_mask)
        
        return encoder_output
        
    def get_embeddings(self):
        if self._cached_source_embeddings is None:
            raise ValueError("Embeddings not computed yet. Call forward() first.")
        return self._cached_source_embeddings
    
    def mask(self, source):
        source_mask = (source != 0).unsqueeze(1).unsqueeze(2)
        return source_mask

# %% [markdown]
# ## Simple test

# %%
seq_len_source = 10
seq_len_target = 10
batch_size = 2
input_vocab_size = 50
target_vocab_size = 50

source = torch.randint(1, input_vocab_size, (batch_size, seq_len_source))

d_model = 512
num_heads = 8
d_ff = 2048
num_layers = 6

model = Transformer(d_model, num_heads, d_ff, num_layers,
                   input_vocab_size, max_len=MAX_SEQ_LEN, dropout=0.1)

model = model.to(device)
source = source.to(device)

output = model(source)
#Expected output shape -> [batch, seq_len_target, target_vocab_size] i.e [2, 10, 50]
print(f'output.shape {output.shape}')
print(source)
# Out:
# output.shape torch.Size([2, 10, 512])
# tensor([[39, 11,  6, 31, 11, 42, 49, 35, 10, 20],
#         [24, 12, 35, 20, 30,  6, 23, 39, 48,  5]], device='cuda:0')

# %% [markdown]
# ## DATA PREPROCESSING: Creation of build_vocab and company...

# %%
def build_vocab(scripts):
    blocks = [block for script in scripts for block in script.split() ]
    block_count = Counter(blocks)
    sorted_block_counts = sorted(block_count.items(), key=lambda x:x[1], reverse=True)
    block2idx = {block: idx for idx, (block, _) in enumerate(sorted_block_counts, 2)}
    block2idx['<pad>'] = 0
    block2idx['<unk>'] = 1
    idx2block = {idx: block for block, idx in block2idx.items()}
    return block2idx, idx2block


class TripletDataset(Dataset):
    def __init__(self, src_sentences, src_block2idx):
        self.src_sentences = src_sentences  # Anchor (source)
        self.src_block2idx = src_block2idx
        
    def __len__(self):
        return len(self.src_sentences)  # Usamos la longitud del conjunto positivo
    
    def __getitem__(self, idx):
        # Obtener las oraciones (anchor, positive, negative)
        src_sentence = self.src_sentences[idx]
        

        # Convertir cada oración en índices
        src_idxs = [self.src_block2idx.get(block, self.src_block2idx['<unk>']) for block in src_sentence.split()]
       

        # Retornar los tensores (anchor, positive, negative)
        return torch.tensor(src_idxs)

# %% [markdown]
# ## TRAIN FUNCTIONS

# %%
def collate_fn(batch):
    src_batch = zip(*batch)
    src_batch = [torch.tensor(seq) for seq in src_batch] 

    #print(trg_batch)
    # Hacemos el padding sin truncar primero
    #trg_batch = torch.nn.utils.rnn.pad_sequence(trg_batch, batch_first=True, padding_value=0)
    #src_batch = torch.nn.utils.rnn.pad_sequence(src_batch, batch_first=True, padding_value=0)
    #neg_batch = torch.nn.utils.rnn.pad_sequence(neg_batch, batch_first=True, padding_value=0)
    
    # Ahora truncamos las secuencias después del padding a MAX_SEQ_LEN
    #trg_batch = trg_batch[:, :MAX_SEQ_LEN]
    #src_batch = src_batch[:, :MAX_SEQ_LEN]
    #neg_batch = neg_batch[:, :MAX_SEQ_LEN]

    src_batch = [torch.nn.functional.pad(seq[:MAX_SEQ_LEN], (0, MAX_SEQ_LEN - len(seq[:MAX_SEQ_LEN])), value=0) for seq in src_batch]

    src_batch = torch.stack(src_batch)
    
    return src_batch

# %%
def train(model, dataloader, loss_function, optimiser, epochs):
    model.train()
    final_anchor_embeddings = []
    final_positive_embeddings = []
    final_negative_embeddings = []
    
    for epoch in range(epochs):
        total_loss = 0
        for i, (anchor_batch, positive_batch, negative_batch) in enumerate(dataloader):
            
            anchor_batch = anchor_batch.to(device)
            positive_batch = positive_batch.to(device)
            negative_batch = negative_batch.to(device)
            
            # Zero grads
            optimiser.zero_grad()

            # Forward para anchor, positive y negative
            anchor_embeddings = model(anchor_batch)
            positive_embeddings = model(positive_batch)
            negative_embeddings = model(negative_batch)
            
            # Almacenar los embeddings solo en el último epoch
            if epoch == epochs - 1:
                final_anchor_embeddings.append(anchor_embeddings.cpu().detach())
                final_positive_embeddings.append(positive_embeddings.cpu().detach())
                final_negative_embeddings.append(negative_embeddings.cpu().detach())


            

            # Calcular la pérdida de Triplet
            loss = loss_function(anchor_embeddings, positive_embeddings, negative_embeddings)

            # Backpropagation y actualización de parámetros
            loss.backward()
            optimiser.step()

            total_loss += loss.item()
            
        avg_loss = total_loss / len(dataloader)
        print(f'Epoch: {epoch + 1}/{epochs}, Loss: {avg_loss:.4f}')
    
    # Concatenar los embeddings del último epoch
    final_anchor_embeddings = torch.cat(final_anchor_embeddings, dim=0)
    final_positive_embeddings = torch.cat(final_positive_embeddings, dim=0)
    final_negative_embeddings = torch.cat(final_negative_embeddings, dim=0)

    return final_anchor_embeddings, final_positive_embeddings, final_negative_embeddings


def evaluate(model, dataloader, reference_embeddings, loss_function=None):
    model = model.to(device)
    model.eval()  # Modo evaluación del modelo
    
    total_loss = 0

    with torch.no_grad():  # No calculamos gradientes en evaluación
        for i, project_batch in enumerate(dataloader):
            # Pasar el batch al dispositivo
            project_batch = project_batch.to(device)
            
            # Obtener embeddings del proyecto actual
            project_embeddings = model(project_batch)
            
    return project_embeddings

# %% [markdown]
# ## **EVALUATION**

# %%
model = torch.load('action_global_scratch_triplet.pth').to(device)
train_src_embeddings = model.get_embeddings()
print("Source embeddings:", train_src_embeddings.shape)
# Out:
# Source embeddings: torch.Size([11, 128, 512])

# %%
class EvaluateModel():
    def __init__(self, project_path, model, train_src_embeddings):
        self.model = model
        self.train_src_embeds = train_src_embeddings
        print(self.train_src_embeds.shape)
        self.distances_cousine = []
        self.distances_euclidean = []
        self.project_path = project_path
        self.scripts = []
        self.dummy_target = self.scripts

        
        self.src_block2idx = {}
        self.src_idx2block = {}
        self.src_vocab_size = None

        # ---- EVALUATION EMBEDDINGS -----
        self.src_embeddings = None
        self.trg_embeddings = None
        self.neg_embeddigns = None
        # --------------------------------

        # Parameters for eval
        self.BATCH_SIZE = 16
        self.loss_function = nn.TripletMarginLoss(margin=1.0)
        self.optimiser = optim.Adam(model.parameters(), lr=0.0001)

        self.dataset = None
        self.dataloader = None

        # Distances
        self.dis_cos = None
        self.dis_eu = None
    
    def execute(self):
        self.locate_project()
        self.add_pads_to_scritps()
        self.build_vocabulary()

        # Create dataset and dataloader
        self.dataset = TripletDataset(self.scripts, self.src_block2idx)
        self.dataloader = DataLoader(self.dataset, batch_size=self.BATCH_SIZE, shuffle=True, collate_fn=collate_fn)
        print("hemos llegado 1")
        # Eval model
        model.eval()
        print("hemos llegado 2")
        self.src_embeddings = evaluate(self.model, self.dataloader, self.loss_function)
        print("hemos llegado 3")
        self.calc_distances()

    def get_train_emb(self):
        train_src_embeddings, _ = self.model.get_embeddings()
        return train_src_embeddings

    def calc_distances(self):
        src_embeddings_global = self.src_embeddings.cpu().detach().numpy()
        trg_embeddings_global = self.train_src_embeds.cpu().detach().numpy()
        print("Shape trg_embeds: ", trg_embeddings_global.shape)
        print("Shape src_embeds: ", src_embeddings_global.shape)
            
        # evaluation embeddings
        src_embeddings_global_shape, trg_embeddings_global_shape = src_embeddings_global.shape, trg_embeddings_global.shape
        src_embeddings_global_new_dim = src_embeddings_global_shape[0] * src_embeddings_global_shape[1]
        trg_embeddings_global_new_dim = trg_embeddings_global_shape[0] * trg_embeddings_global_shape[1]
        src_embeddings_global, trg_embeddings_global = src_embeddings_global.reshape(src_embeddings_global_new_dim, 512), trg_embeddings_global.reshape(trg_embeddings_global_new_dim, 512)
    
        # Comparar embeddings de evaluación con los embeddings de entrenamiento
        cos_sim = cosine_similarity(src_embeddings_global, trg_embeddings_global)
        euclidean_dist = euclidean_distances(src_embeddings_global, trg_embeddings_global)

        self.dis_cos = cos_sim.mean()
        self.dis_eu = euclidean_dist.mean()

    def get_distances(self):
        return self.dis_cos, self.dis_eu

    def build_vocabulary(self):
        self.src_block2idx, self.src_idx2block = self.build_vocab()
        self.src_vocab_size = len(self.src_block2idx)
        self.trg_block2idx, self.trg_idx2block = self.src_block2idx, self.src_idx2block
        self.trg_vocab_size = len(self.trg_block2idx)

    def build_vocab(self):
        blocks = [block for script in self.scripts for block in script.split() ]
        block_count = Counter(blocks)
        sorted_block_counts = sorted(block_count.items(), key=lambda x:x[1], reverse=True)
        block2idx = {block: idx for idx, (block, _) in enumerate(sorted_block_counts, 2)}
        block2idx['<pad>'] = 0
        block2idx['<unk>'] = 1
        idx2block = {idx: block for block, idx in block2idx.items()}
        return block2idx, idx2block

    def load_json_project(self, path_projectsb3):
        try:
            zip_file = ZipFile(path_projectsb3, "r")
            json_project = json.loads(zip_file.open("project.json").read())
            return json_project
        except BadZipFile:
            print('Bad zipfile')

    def process(self, json_project):
        seq_num = 0
        dict_total_blocks = {}
        
        list_total_blocks = []
    
        for key, list_info in json_project.items():
            if key == "targets":
                for dict_target in list_info:
                    target_name = dict_target.get('name')
                    if target_name:
                        dict_total_blocks[target_name] = {}
                        dict_total_blocks[target_name][f'Seq_{seq_num}'] = []
                    blocks = dict_target.get('blocks')
                    if blocks:
                        for block_id, block_info in blocks.items():
                            if isinstance(block_info, dict):
                                topLevel = block_info.get('topLevel')
                                if topLevel:
                                    seq_num += 1
                                    dict_total_blocks[target_name][f'Seq_{seq_num}'] = []
                                opcode = block_info.get('opcode')
                                if opcode:
                                    
                                    dict_total_blocks[target_name][f'Seq_{seq_num}'].append(opcode)
                                list_total_blocks.append(block_info)
                                #dict_total_blocks[block_id] = block_info
        return dict_total_blocks

    def locate_project(self):
        #sb3_path = os.path.join('.','sb3_action_global',project)
        if os.path.isfile(self.project_path):
            #print(project)
            json_project = self.load_json_project(self.project_path)
            dict_total_blocks = self.process(json_project)
    
            for sprite, seqs in dict_total_blocks.items():
                for idx, block_list in seqs.items():
                    if block_list != []:
                        self.scripts.append(" ".join(block_list))
        else:
            raise("The project does not exists.")

    def add_pads_to_scritps(self):
        self.scripts = ['<sos> ' + script + ' <eos>' for script in self.scripts]

# %%
#sb3_project = os.path.join("./Beat the Robot.sb3")
sb3_project = os.path.join("./storytelling.sb3")

evaluation_obj = EvaluateModel(sb3_project, model, train_src_embeddings)
evaluation_obj.execute()
# Out:
# torch.Size([11, 128, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 128, 512)
# Shape src_embeds:  (5, 128, 512)

# %%
dist_cos, dist_eu = evaluation_obj.get_distances()
print(f"Distancia coseno: {dist_cos}")
print(f"Distancia euclidea: {dist_eu}")
# Out:
# Distancia coseno: 0.12439966946840286
# Distancia euclidea: 543.4035034179688

# %% [markdown]
# ## EVALUATE EACH ONE OF GLOBAL PROJECT

# %%
metrics = pd.read_csv('metrics_attr.csv')

# Filter by Action Genre
metrics_action = metrics[(metrics['Main Genre'] == 'Action')]

# Check the filenames for collect
filenames_action = list(metrics_action['Name'])
# Create txt for made the shell script
with open('filenames_action_global.txt', 'w') as names:
     for name in filenames_action:
        names.write(name + '\n')

# %%
dist_cos_global = []
dist_eu_global = []
print(len(filenames_action))
evaluations = {}
for idx, project in enumerate(filenames_action):
    print(f"Project {idx}/{len(filenames_action)}")
    sb3_path = os.path.join('.','sb3_action_global',project)
    if os.path.isfile(sb3_path):
        #print(project)
        model = torch.load('action_global_scratch2.pth')
        train_src_embeddings = model.get_embeddings()
        
        #evaluations[project] = EvaluateModel(sb3_path, model, train_src_embeddings)
        #evaluations[project].execute()

        eval = EvaluateModel(sb3_path, model, train_src_embeddings)
        eval.execute()
        dist_cos, dist_eu = eval.get_distances()
        #dist_cos, dist_eu = evaluations[project].get_distances()
        dist_cos_global.append(dist_cos)
        dist_eu_global.append(dist_eu)
# Out:
# 312
# Project 0/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 1/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (7, 128, 512)
# Project 2/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 3/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 4/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (7, 128, 512)
# Project 5/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 6/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 7/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 8/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 9/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 10/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (6, 128, 512)
# Project 11/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 12/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 13/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 14/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 15/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 16/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 17/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 18/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 19/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 20/312
# Project 21/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (6, 128, 512)
# Project 22/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 23/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 24/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 25/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 26/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 27/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (11, 128, 512)
# Project 28/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (7, 128, 512)
# Project 29/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 30/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 31/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 32/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (9, 128, 512)
# Project 33/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 34/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 35/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 36/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 37/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 38/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 39/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 40/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 41/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 42/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 43/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 44/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 45/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 46/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 47/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 48/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 49/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 50/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 51/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 52/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 53/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 54/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 55/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 56/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 57/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 58/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 59/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 60/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 61/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 62/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 63/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 64/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 65/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 66/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 67/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 68/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 69/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 70/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 71/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 72/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 73/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 74/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 75/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 76/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 77/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 78/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 79/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 80/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 81/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 82/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 83/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 84/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 85/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 86/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 87/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 88/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 89/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (7, 128, 512)
# Project 90/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 91/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 92/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 93/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 94/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (15, 128, 512)
# Project 95/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 96/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (6, 128, 512)
# Project 97/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 98/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 99/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 100/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 101/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 102/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 103/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 104/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 105/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (8, 128, 512)
# Project 106/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 107/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 108/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 109/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 110/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 111/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 112/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 113/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 114/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 115/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 116/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 117/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 118/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (6, 128, 512)
# Project 119/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 120/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 121/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (6, 128, 512)
# Project 122/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (7, 128, 512)
# Project 123/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 124/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 125/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 126/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 127/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (7, 128, 512)
# Project 128/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 129/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 130/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 131/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 132/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 133/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 134/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (6, 128, 512)
# Project 135/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 136/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 137/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 138/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 139/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 140/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 141/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 142/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 143/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 144/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 145/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (6, 128, 512)
# Project 146/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 147/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (7, 128, 512)
# Project 148/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 149/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 150/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 151/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 152/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 153/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 154/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 155/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 156/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 157/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 158/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 159/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (8, 128, 512)
# Project 160/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 161/312
# Project 162/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (14, 128, 512)
# Project 163/312
# Project 164/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 165/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 166/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 167/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (6, 128, 512)
# Project 168/312
# Project 169/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 170/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 171/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 172/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (10, 128, 512)
# Project 173/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 174/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 175/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (18, 128, 512)
# Project 176/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 177/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 178/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 179/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 180/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 181/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 182/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 183/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 184/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 185/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 186/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 187/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 188/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 189/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 190/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 191/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 192/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 193/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 194/312
# Project 195/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 196/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 197/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 198/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 199/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 200/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 201/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 202/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 203/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 204/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 205/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (6, 128, 512)
# Project 206/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 207/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 208/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 209/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 210/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 211/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 212/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 213/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 214/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 215/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 216/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 217/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 218/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 219/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 220/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 221/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 222/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 223/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (9, 128, 512)
# Project 224/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (8, 128, 512)
# Project 225/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 226/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 227/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 228/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 229/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 230/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 231/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 232/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 233/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 234/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 235/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 236/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 237/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 238/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 239/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 240/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 241/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 242/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 243/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 244/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 245/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 246/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 247/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 248/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 249/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 250/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 251/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 252/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 253/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 254/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 255/312
# Project 256/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 257/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 258/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 259/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 260/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 261/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 262/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 263/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 264/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (7, 128, 512)
# Project 265/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 266/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 267/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 268/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 269/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 270/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 271/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 272/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 273/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 274/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 275/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 276/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 277/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 278/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (6, 128, 512)
# Project 279/312
# Project 280/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 281/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 282/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 283/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (14, 128, 512)
# Project 284/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 285/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 286/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 287/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (10, 128, 512)
# Project 288/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 289/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 290/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 291/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 292/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 293/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 294/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 295/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 296/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 297/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 298/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 299/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 300/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 301/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 302/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 303/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 304/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 305/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (3, 128, 512)
# Project 306/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (7, 128, 512)
# Project 307/312
# Project 308/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (4, 128, 512)
# Project 309/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (5, 128, 512)
# Project 310/312
# torch.Size([11, 12, 512])
# hemos llegado 1
# hemos llegado 2
# hemos llegado 3
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (9, 128, 512)
# Project 311/312

# %%
#print(dist_cos_global)


projects_simil = {project: similarity for project, similarity in zip(filenames_action, dist_cos_global)}
projects_simil = dict(sorted(projects_simil.items(), key=lambda item: item[1]))
print(projects_simil['Nora + Sage.sb3'])
print(projects_simil)
# Out:
# 0.1389008
# {'Polar Bear Fixes Climate Change.sb3': 0.08266613, 'David & Peter.sb3': 0.09001841, 'Gabe Umut-2.sb3': 0.09130949, 'Reducing Meat Consumption.sb3': 0.091474764, 'help the polar bear.sb3': 0.091627285, 'Brick Breaker remix.sb3': 0.092268914, 'climate change pong.sb3': 0.09252689, 'Climate Change Game_(2).sb3': 0.09269398, 'Greenhouse Gases Game.sb3': 0.09335795, 'Carbon Run.sb3': 0.0934551, 'Collect the CO2.sb3': 0.096609145, 'Reforestation and Deforestation- Saving this land.sb3': 0.09691623, 'Climate Change Catch Game.sb3': 0.09791252, 'Climate Control_(2).sb3': 0.09792567, 'Reducing Ocean Acidification.sb3': 0.09824653, 'Climate Change Project: Saving the penguin.sb3': 0.09891691, "Bryan and Mark's Game Project.sb3": 0.09915083, 'Super Carbon Bros.sb3': 0.09915173, 'Sammie and Alex Carbon Cycle Project.sb3': 0.10047329, 'Mark Jeremy.sb3': 0.10134343, 'gobo global harm.sb3': 0.10143384, 'Yuval and Rebecca Water cycle.sb3': 0.101533644, 'jabby.sb3': 0.101621166, "Franki and Elena's game.sb3": 0.1019437, 'Save the Trees!.sb3': 0.10201048, 'Fortnite: Climate Change Edition.sb3': 0.1026145, 'Climate Change Game_(5).sb3': 0.1032068, 'Mitigation Game.sb3': 0.10322157, 'Climate Pong.sb3': 0.10363151, 'Class Project Sage and Nora.sb3': 0.10476158, 'Shayan and Jeff.sb3': 0.10490112, 'Heat absorber.sb3': 0.10505023, 'Untitled-2_(3).sb3': 0.105636396, 'Untitled-3_(4).sb3': 0.10563641, 'Scratch Project.sb3': 0.10633315, 'Deforestation Game_(2).sb3': 0.10646733, 'Global Warming Game.sb3': 0.107277185, 'IvGroup7s2 Max Dylan.sb3': 0.10735509, 'Patrick and Elaine.sb3': 0.107519664, 'The Fun Ocean Game.sb3': 0.1078794, 'Zach Chase game.sb3': 0.10857125, 'Save the Earth.sb3': 0.10858276, '`.sb3': 0.10859868, 'Climate Change Game Hannah and Andrew.sb3': 0.1087871, 'Save the World from Co2!.sb3': 0.10888193, 'kill the CO2.sb3': 0.10888968, "Jack and Zach's Epic Adventure.sb3": 0.109036624, 'Sarita Gabe Game.sb3': 0.109216675, 'Save the Sky.sb3': 0.10940591, 'JakeJaleikaAnimationChallenge.sb3': 0.10957289, 'World and Climate Changing Game_(2).sb3': 0.11029273, 'Co2 Survival.sb3': 0.11040594, 'Troubled Waters.sb3': 0.11052757, 'Welcome to the Greenhouse.sb3': 0.11062356, 'Untitled-2_(2).sb3': 0.11066556, 'ENOZO STOPPER.sb3': 0.110736005, 'Grayson Josh Animation Challenge.sb3': 0.11122762, 'Rising Co2 Level.sb3': 0.11137751, 'Climate Change Choose Your Own Adventure.sb3': 0.11151883, 'make the trees dissapear.sb3': 0.11154533, 'Farmer Sam and His Cows.sb3': 0.11164151, 'Take Action! - heymynamestrey.sb3': 0.11175112, 'CO2 fr.sb3': 0.112054415, 'Deforestation Disaster.sb3': 0.11217612, "Clara and Mira's Project.sb3": 0.11248457, 'Elsa saves the world alebdo style.sb3': 0.11277214, 'Falling Fruit Fiesta.sb3': 0.11303811, 'YOUNES AND MARAT QUIZ.sb3': 0.113098, 'Car Bike Atmosphere.sb3': 0.113155276, 'Cloud Catching.sb3': 0.11325474, 'Destroy the World.sb3': 0.113406114, 'Deforestation game.sb3': 0.11352492, 'Ice Pong.sb3': 0.11369397, 'CO2 journey.sb3': 0.11377349, 'Kevin_Ben Animation Challenge.sb3': 0.11387835, 'Save the Climate.sb3': 0.11391079, 'jumpy tree.sb3': 0.11400122, 'Save The Atmosphere.sb3': 0.11401202, 'The Night sky.sb3': 0.114079714, 'Leaf Me Alone Carbon.com.net.org.io.exe.mp3.mp4.sb3': 0.11418982, 'Earth vs. Floods.sb3': 0.11422191, 'co2 game.sb3': 0.11429609, 'catch the CO2 by Olivia and Polina.sb3': 0.11457463, 'Forest Fire Scratch Game Akash Adrien.sb3': 0.11466346, 'Cole and Ryan.sb3': 0.114839576, 'Save the Fishy.sb3': 0.11491855, 'Factory Game Thalia and Jehan.sb3': 0.11492385, 'Building wackamole in the city of Hainsboro.sb3': 0.11545408, 'DO NOT PLAY THIS GAME. PLAY THE OTHER ONE!.sb3': 0.115628935, 'THE GLOBAL WARMING game!.sb3': 0.1158272, 'Jocey and Natasha.sb3': 0.11610224, 'Zach and Nico.sb3': 0.11611517, 'factory.sb3': 0.11616665, 'Science Game.sb3': 0.1162225, 'Eat The Carbon by Barry and Kyrene.sb3': 0.11622381, "Julia and Meri's Game.sb3": 0.11625605, 'Factory Pollution.sb3': 0.11633722, 'Ryan D and Weller B CC Game ...

# %%
print(sum(dist_cos_global)/len(dist_cos_global))
# Out:
# 0.1224679224709473

# %%
#sb3_project = os.path.join("./Beat the Robot.sb3")
model = torch.load('action_global_scratch2.pth')
train_src_embeddings, _ = model.get_embeddings()
sb3_project = os.path.join("./WindowsSimulator.sb3")

evaluation_obj = EvaluateModel(sb3_project, model, train_src_embeddings)
evaluation_obj.execute()

dist_cos, dist_eu = evaluation_obj.get_distances()
print(f"Distancia coseno: {dist_cos}")
print(f"Distancia euclidea: {dist_eu}")
# Out:
# torch.Size([11, 12, 512])
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [96,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [97,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [98,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [99,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [100,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [101,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [102,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [103,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [104,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [105,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [106,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [107,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [108,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [109,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [110,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [111,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [112,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [113,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [114,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [115,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [116,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [117,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [118,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [119,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [120,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [121,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [122,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [123,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [124,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [125,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [126,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [127,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [58,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [0,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [1,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [2,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [3,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [4,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [5,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [6,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [7,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [8,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [9,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [10,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [11,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [12,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [13,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [14,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [15,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [16,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [17,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [18,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [19,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [20,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [21,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [22,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [23,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [24,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [25,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [26,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [27,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [28,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [29,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [30,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [31,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [32,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [33,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [34,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [35,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [36,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [37,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [38,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [39,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [40,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [41,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [42,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [43,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [44,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [45,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [46,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [47,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [48,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [49,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [50,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [51,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [52,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [53,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [54,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [55,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [56,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [57,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [58,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [59,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [60,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [61,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [62,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [63,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [64,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [65,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [66,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [67,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [68,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [69,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [70,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [71,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [72,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [73,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [74,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [75,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [76,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [77,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [78,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [79,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [80,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [81,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [82,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [83,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [84,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [85,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [86,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [87,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [88,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [89,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [90,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [91,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [92,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [93,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [94,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ../aten/src/ATen/native/cuda/Indexing.cu:1146: indexSelectLargeIndex: block: [57,0,0], thread: [95,0,0] Assertion `srcIndex < srcSelectDimSize` failed.
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[13], line 7
#       4 sb3_project = os.path.join("./WindowsSimulator.sb3")
#       6 evaluation_obj = EvaluateModel(sb3_project, model, train_src_embeddings)
# ----> 7 evaluation_obj.execute()
#       9 dist_cos, dist_eu = evaluation_obj.get_distances()
#      10 print(f"Distancia coseno: {dist_cos}")
#
# Cell In[11], line 50, in EvaluateModel.execute(self)
#      48 # Eval model
#      49 model.eval()
# ---> 50 self.src_embeddings, self.trg_embeddings = evaluate(self.model, self.dataloader, self.loss_function)
#      51 self.calc_distances()
#
# Cell In[9], line 38, in evaluate(model, dataloader, loss_function)
#      35         trg_batch = trg_batch.to(device)
#      37         # Propaga hacia adelante
# ---> 38         outputs = model(src_batch, src_batch)
#      39         src_embeddings_test, trg_embeddings_test = model.get_embeddings()
#      41         # Calcula la pérdida
#      42         #loss = loss_function(outputs.view(-1, trg_vocab_size), trg.view(-1))
#      43         #total_loss += loss.item() * src.size(0)
#    (...)
#      46 #avg_loss = total_loss / total_samples
#      47 #print(f'Average Loss: {avg_loss:.4f}')
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# Cell In[5], line 21, in Transformer.forward(self, source, target)
#      19 source_mask, target_mask = self.mask(source, target)
#      20 # Embedding and positional Encoding
# ---> 21 source = self.encoder_embedding(source) * math.sqrt(self.encoder_embedding.embedding_dim)
#      22 self._cached_source_embeddings = source
#      23 source = self.pos_embedding(source)
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/module.py:1501, in Module._call_impl(self, *args, **kwargs)
#    1496 # If we don't have any hooks, we want to skip the rest of the logic in
#    1497 # this function, and just call forward.
#    1498 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1499         or _global_backward_pre_hooks or _global_backward_hooks
#    1500         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1501     return forward_call(*args, **kwargs)
#    1502 # Do not call functions when jit is used
#    1503 full_backward_hooks, non_full_backward_hooks = [], []
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/modules/sparse.py:162, in Embedding.forward(self, input)
#     161 def forward(self, input: Tensor) -> Tensor:
# --> 162     return F.embedding(
#     163         input, self.weight, self.padding_idx, self.max_norm,
#     164         self.norm_type, self.scale_grad_by_freq, self.sparse)
#
# File /usr/local/lib/python3.9/site-packages/torch/nn/functional.py:2210, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2204     # Note [embedding_renorm set_grad_enabled]
#    2205     # XXX: equivalent to
#    2206     # with torch.no_grad():
#    2207     #   torch.embedding_renorm_
#    2208     # remove once script supports set_grad_enabled
#    2209     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2210 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: CUDA error: device-side assert triggered
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
#sb3_project = os.path.join("./Beat the Robot.sb3")
#model = torch.load('action_global_scratch2.pth')
#train_src_embeddings, _ = model.get_embeddings()
sb3_project = os.path.join("./piano.sb3")

evaluation_obj = EvaluateModel(sb3_project, model, train_src_embeddings)
evaluation_obj.execute()

dist_cos, dist_eu = evaluation_obj.get_distances()
print(f"Distancia coseno: {dist_cos}")
print(f"Distancia euclidea: {dist_eu}")
# Out:
# torch.Size([11, 12, 512])
# Evaluation Completed
# Shape trg_embeds:  (11, 12, 512)
# Shape src_embeds:  (7, 36, 512)
# Distancia coseno: 0.31856071949005127
# Distancia euclidea: 492.714599609375
